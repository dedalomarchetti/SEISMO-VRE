# %% [markdown]
# # Notebook to download the data for SEISMO-VRE
# Except where otherwise noted, this Jupyter Notebook is made available under the GPL-3.0 license. For details, please see the `LICENSE` file in the main directory.
# # Python Version
#
# ## Data list
# ### Analyses workflow
# 1. [Atmospheric data from NASA](#Atmosphere-data)
# 2. [Ionosphere Swarm data from ESA](#Ionosphere-data)
# 3. [Geomagnetic indexes (Dst and ap)](#Geomagnetic-indexes)
# 4. [North geomagnetic pole](#North-geomagnetic-pole).
#
# ### Reconfigurable parameters
# **Please, remember to update the global variables according to the earthquake you want to analyse in the main notebook**

# %%
#Global variables initialization

from cdflib import CDF, cdfepoch
from datetime import datetime, timedelta
import glob
import io
import math
import numpy as np
import os
import pandas as pd
import requests
import scipy.io
from scipy.io import savemat
import sys
import time
from typing import Union
import viresclient
from viresclient import set_token
from viresclient import SwarmRequest
import xarray as xr
import csv
from tqdm import tqdm
from scipy.io import savemat # Import scipy for .mat file saving


# Earthquake origin time
EQ_year = 2016
EQ_month = 8
EQ_day = 24
EQ_hour = 1
EQ_minute = 36
EQ_second = 32

# Epicenter latitude and longitude
EPILAT = 42.6980
EPILON = 13.2340

# Mainshock magnitude and depth
EQ_mag = 6.5
EQ_depth = 10

# Fault strike
# Here is inserted a mean strike of the two main faults: Amatrice 155 and Norcia 151.
# This strike must be a positive value.
Fault_strike = 153

# Time windows
day_before = 8 * 30  # example,  8*30 days before
day_after = 0

# %% [markdown]
# ## Atmosphere data
#
# The atmospheric analysis uses the MERRA2 climatological archive data from NASA (doi: <a href="https://doi.org/10.5067/KLICLTZ8EM9D"> 10.5067/KLICLTZ8EM9D</a>).
#
# **If you need to change the case study, you must delete the file `Atmospheric_data_from_MERRA2.mat`**. Otherwise, the analysis could potentially mix data from different events.
#
# In this session the data from MERRA-2 Climatological archive will be downloaded and analysed
# **Important note:**
# The MERRA-2 data are open but require a free account on EarthData Nasa portal. The following line will ask you your username (generally your registration email) and your password in order to download the data.
#
# In order to mask the password the Matlab tool logindlg has been used. Proper credit to: Jeremy Smith (2025). login (https://www.mathworks.com/matlabcentral/fileexchange/8499-login), MATLAB Central File Exchange. Retrieved January 25, 2025.

# %%
# --- CONSTANTS AND CONFIGURATION ---
DATA_DIR = 'data'
OUTPUT_FILENAME = os.path.join(DATA_DIR, 'Atmospheric_data_from_MERRA2_local.csv')
MATLAB_OUTPUT_FILENAME = os.path.join(DATA_DIR, 'Atmospheric_data_from_MERRA2.mat') # MATLAB output filename

# NASA Earthdata credentials (NOTE: These are placeholder credentials and should be handled securely)
NASA_USERNAME = "username" # YOU NEED TO INSERT YOUR EO-NASA USERNAME HERE
NASA_PASSWORD = "password" # YOU NEED TO INSERT YOUR EO-NASA PASSWORD HERE

# MERRA2 products to download
MERRA_PRODUCTS = {
    'inst1_2d_int_Nx': {'url_shortname': 'M2I1NXINT', 'variables': {'TQV': 'TCWV'}}, # Total Column Water Vapor
    'tavg1_2d_aer_Nx': {'url_shortname': 'M2T1NXAER', 'variables': {'DMSSMASS': 'DMS', 'SO2SMASS': 'SO2', 'TOTEXTTAU': 'AOT'}}, # Aerosols: DMS, SO2, Aerosol Optical Thickness
    'tavg1_2d_chm_Nx': {'url_shortname': 'M2T1NXCHM', 'variables': {'COSC': 'CO', 'TO3': 'TO3'}}, # Chemistry: Carbon Monoxide, Ozone
    'inst1_2d_lfo_Nx': {'url_shortname': 'M2I1NXLFO', 'variables': {'QLML': 'HUM', 'TLML': 'SAT'}}, # Low Frequency: Humidity, Surface Air Temperature
    'tavg1_2d_flx_Nx': {'url_shortname': 'M2T1NXFLX', 'variables': {'EFLUX': 'SLHF', 'PRECTOT': 'RAIN'}} # Fluxes: Surface Latent Heat Flux, Total Precipitation
}

MAX_RETRIES = 6
RETRY_DELAYS_SECONDS = [10, 30, 60, 180, 300, 600]

# --- FUNCTIONS ---

def datetime_to_matlab_datenum(dt: datetime) -> float:
    """
    Converts a Python datetime.datetime object to the MATLAB datenum format.
    
    MATLAB datenum is the number of days since 0000-01-00 (MATLAB epoch).
    Python's ordinal date is the number of days since 0001-01-01 (Python epoch).
    A 366-day correction is applied to account for the epoch difference.
    """
    if not isinstance(dt, datetime):
        return np.nan # Handle invalid or missing values

    # 1. Calculate integer days (integer part of datenum)
    # The correction of 366 days accounts for the epoch shift (MATLAB year 0000 vs Python year 0001)
    datenum_days = dt.toordinal() + 366

    # 2. Return the full datenum (integer days + fraction)
    return float(datenum_days)


def get_merra_version(date_obj: datetime) -> str:
    """Returns the correct MERRA2 data version based on the date."""
    if date_obj < datetime(1992, 1, 1): return 'MERRA2_100'
    if date_obj < datetime(2001, 1, 1): return 'MERRA2_200'
    if date_obj < datetime(2011, 1, 1): return 'MERRA2_300'
    if (datetime(2020, 9, 1) <= date_obj <= datetime(2020, 9, 30)) or \
       (datetime(2021, 6, 1) <= date_obj <= datetime(2021, 9, 30)):
        return 'MERRA2_401'
    return 'MERRA2_400'

def download_merra_file(url: str, local_path: str) -> bool:
    """Downloads the MERRA2 file with authentication and retry logic."""
    for attempt in range(MAX_RETRIES):
        try:
            with requests.get(url, auth=(NASA_USERNAME, NASA_PASSWORD), stream=True, timeout=60) as r:
                if r.status_code == 200:
                    with open(local_path, 'wb') as f:
                        for chunk in r.iter_content(chunk_size=8192):
                            f.write(chunk)
                    return True
                else:
                    print(f"HTTP {r.status_code} for {url}")
        except Exception as e:
            print(f"Attempt {attempt+1}/{MAX_RETRIES} failed for {url}. Error: {e}")
        if attempt < MAX_RETRIES - 1:
            delay = RETRY_DELAYS_SECONDS[attempt]
            print(f"Retrying in {delay} seconds...")
            time.sleep(delay)
    print(f"WARNING: Failed to download {url}")
    return False

def process_merra_day(date_obj: datetime, bbox: dict, ut_hour: int) -> dict:
    """
    Downloads, reads, processes (subsets and averages), and safely deletes 
    a single day's MERRA2 file. Returns the aggregated data.
    """
    year, month, day = date_obj.year, date_obj.month, date_obj.day
    version_f = get_merra_version(date_obj)
    
    # The reference time for extraction is the day's date + ut_hour + 30 minutes
    time_target_dt = datetime(date_obj.year, date_obj.month, date_obj.day, ut_hour, 30)
    
    # Store the complete datetime object. It will be converted to string for CSV 
    # and to datenum for MATLAB later.
    daily_data = {"date": time_target_dt}
    base_url = "https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax"

    for product_name, config in MERRA_PRODUCTS.items():
        # Construct the remote OPeNDAP URL
        file_path = (f"MERRA2/{config['url_shortname']}.5.12.4/{year}/{month:02d}/"
                     f"{version_f}.{product_name}.{year}{month:02d}{day:02d}.nc4.nc4?")
        opendap_url = f"{base_url}/{file_path}"
        # Define the local temporary file path
        local_file = os.path.join(DATA_DIR, f"{version_f}.{product_name}.{year}{month:02d}{day:02d}.nc4")

        # Download the file
        if not download_merra_file(opendap_url, local_file):
            # If download fails, fill with NaN and continue to next product
            for df_col in config['variables'].values():
                daily_data[df_col] = np.nan
            continue

        # Read and process data safely
        try:
            # Open the downloaded NetCDF file with xarray
            ds = xr.open_dataset(local_file, engine="netcdf4", decode_times=True)
            try:
                # Define geographical and time slicing parameters
                lat_slice = slice(bbox['min_lat'], bbox['max_lat'])
                lon_slice = slice(bbox['min_lon'], bbox['max_lon'])
                time_target = np.datetime64(time_target_dt)

                for nc_var, df_col in config['variables'].items():
                    if nc_var not in ds:
                        # Variable missing in the file
                        daily_data[df_col] = np.nan
                        continue
                    
                    # Spatial subsetting
                    spatial_subset = ds[nc_var].sel(lat=lat_slice, lon=lon_slice)
                    
                    # Temporal subsetting if 'time' dimension exists
                    if 'time' in spatial_subset.dims:
                        # Find the closest time step to the target time
                        data_subset = spatial_subset.sel(time=time_target, method='nearest')
                    else:
                        # For variables without a time dimension
                        data_subset = spatial_subset
                        
                    # Calculate the spatial mean and store the value
                    daily_data[df_col] = float(data_subset.mean().values)
            finally:
                ds.close()  # Explicitly close the file before deletion
        except Exception as e:
            print(f"Error reading {local_file}: {e}")
            # Fill with NaN if processing fails
            for df_col in config['variables'].values():
                if df_col not in daily_data:
                    daily_data[df_col] = np.nan
        finally:
            # Delete the local file after processing
            if os.path.exists(local_file):
                try:
                    os.remove(local_file)
                except PermissionError:
                    print(f"Cannot delete {local_file}, file still in use. Manual cleanup needed.")
                    pass

    return daily_data


# --- FUNZIONE save_to_matlab MODIFICATA PER IL NUOVO FORMATO ---
def save_to_matlab(df: pd.DataFrame, filename: str):
    """
    Saves the pandas DataFrame to a MATLAB .mat file.
    It structures the output as: {Time_Var1, Var1, Time_Var2, Var2, ...}
    """
    mat_dict = {}
    
    # Prepare the datenum converter
    datenum_converter = np.vectorize(datetime_to_matlab_datenum)
    
    # 1. Convert the array of datetime objects (from the 'date' column) to datenum once
    # This array will be used for all variables
    time_datenum_array = datenum_converter(df['date'].values)
    
    # 2. Iterate through all data columns and create the paired Time_VarX variables
    # The 'date' column contains the original datetime objects and should not be saved as data
    data_columns = [col for col in df.columns if col != 'date']
    
    for col in data_columns:
        # Save the datenum array first, using a custom name (e.g., Time_TCWV)
        time_var_name = f"Time_{col}"
        mat_dict[time_var_name] = time_datenum_array
        
        # Save the data array next
        mat_dict[col] = df[col].values.astype(float) 

    # Save the dictionary to a .mat file (v5 format)
    savemat(filename, mat_dict)
    print(f"\nData successfully saved to MATLAB format: {filename}")


# --- MAIN EXECUTION ---
def main():
    # 1. Setup
    os.makedirs(DATA_DIR, exist_ok=True)
    
    # 2. Calculate Bounding Box (BBox) and Target Time
    # Calculate radius according to Dobrovolsky's formula (in degrees)
    radius_dobrovolsky = 10 ** (0.43 * EQ_mag) / 111.0
    # Calculate lat/lon half-radii for a square BBox (using sqrt(2) for simplification)
    lat_radius, lon_radius = radius_dobrovolsky / np.sqrt(2), radius_dobrovolsky / np.sqrt(2)
    bbox = {
        "min_lat": EPILAT - lat_radius,
        "max_lat": EPILAT + lat_radius,
        "min_lon": EPILON - lon_radius,
        "max_lon": EPILON + lon_radius
    }

    # Convert longitude to UT hour (Local Midnight Approximation)
    local_midnight = -EPILON / 15.0 # Time difference from UTC in hours (15 degrees/hour)
    ut_hour = int(round(local_midnight)) % 24 # Round to nearest hour and ensure it's within [0, 23]

    # 3. Generate Dates to Analyze
    start_year = 1980
    end_year = datetime.now().year - 1
    days_to_analyze = []
    # Loop through all years from start_year to end_year
    for year in range(start_year, end_year + 1):
        center_date = datetime(year, EQ_month, EQ_day) # The 'earthquake' date for that year
        # Define the window around the 'earthquake' date
        start_date, end_date = center_date - timedelta(days=day_before), center_date + timedelta(days=day_after)
        # Generate and add dates within the window
        # pd.date_range ensures standard datetime objects are used
        days_to_analyze.extend(pd.date_range(start_date, end_date))
    # Remove duplicates (in case windows overlap) and sort
    days_to_analyze = sorted(list(set(days_to_analyze)))

    # 4. Prepare CSV Output
    # The 'date' column in the CSV will store the full time as a string.
    all_columns = ["date"] + [col for cfg in MERRA_PRODUCTS.values() for col in cfg['variables'].values()]

    # Read existing dates to skip already processed days
    existing_dates = set()
    if os.path.isfile(OUTPUT_FILENAME):
        try:
            # Read the existing CSV for the update phase
            df_check = pd.read_csv(OUTPUT_FILENAME)
            # Use string format (Y-m-d H:M:S) for comparison
            existing_dates = set(df_check["date"].astype(str))
        except:
            print(f"WARNING: Could not read existing dates from {OUTPUT_FILENAME}. Processing all days.")
            pass
            
    # 5. Main Processing Loop
    pbar = tqdm(total=len(days_to_analyze), desc="Processing days")
    new_data_rows = [] # List to collect new data before appending

    for day_obj in days_to_analyze:
        # The reference string for the check must include hour and minutes
        day_str_check = datetime(day_obj.year, day_obj.month, day_obj.day, ut_hour, 30).strftime("%Y-%m-%d %H:%M:%S")
        
        # Skip if already processed
        if day_str_check in existing_dates:
            pbar.update(1)
            continue

        # Process the day (download, subset, average)
        daily_results = process_merra_day(day_obj, bbox, ut_hour)
        
        # Convert the full datetime object to a standard string for CSV saving
        daily_results['date'] = daily_results['date'].strftime("%Y-%m-%d %H:%M:%S") 
        new_data_rows.append(daily_results)

        pbar.update(1)

    pbar.close()
    
    # 5b. Write only the new data
    if new_data_rows:
        # If the file exists, append. Otherwise, write the header.
        write_header = not os.path.isfile(OUTPUT_FILENAME)
        df_new = pd.DataFrame(new_data_rows, columns=all_columns)
        # Append new data to the CSV file
        df_new.to_csv(OUTPUT_FILENAME, mode='a', header=write_header, index=False)
        print(f"\nAppended {len(new_data_rows)} new data rows to {OUTPUT_FILENAME}")
    else:
        print("\nProcessing complete. No new data to append.")


    # 6. Save to MATLAB .mat file
    # Read the final, consolidated CSV data into a DataFrame
    try:
        # Read the complete CSV file, converting the 'date' string column back to datetime objects
        final_df = pd.read_csv(OUTPUT_FILENAME, parse_dates=['date']) 
        save_to_matlab(final_df, MATLAB_OUTPUT_FILENAME)
        
        # Delete the temporary CSV file
        if os.path.exists(OUTPUT_FILENAME):
            os.remove(OUTPUT_FILENAME)
            print(f"Successfully deleted temporary CSV file: {OUTPUT_FILENAME}")
            
    except Exception as e:
        print(f"FATAL ERROR: Could not read CSV file to save to MATLAB format. Error: {e}")

if __name__ == "__main__":
    main()
# Out:
# Processing days:   0%|          | 0/10845 [00:00<?, ?it/s]
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2I1NXINT.5.12.4/1979/12/MERRA2_100.inst1_2d_int_Nx.19791228.nc4.nc4?
# Retrying in 10 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2I1NXINT.5.12.4/1979/12/MERRA2_100.inst1_2d_int_Nx.19791228.nc4.nc4?
# Retrying in 30 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2I1NXINT.5.12.4/1979/12/MERRA2_100.inst1_2d_int_Nx.19791228.nc4.nc4?
# Retrying in 60 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2I1NXINT.5.12.4/1979/12/MERRA2_100.inst1_2d_int_Nx.19791228.nc4.nc4?
# Retrying in 180 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2I1NXINT.5.12.4/1979/12/MERRA2_100.inst1_2d_int_Nx.19791228.nc4.nc4?
# Retrying in 300 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2I1NXINT.5.12.4/1979/12/MERRA2_100.inst1_2d_int_Nx.19791228.nc4.nc4?
# WARNING: Failed to download https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2I1NXINT.5.12.4/1979/12/MERRA2_100.inst1_2d_int_Nx.19791228.nc4.nc4?
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXAER.5.12.4/1979/12/MERRA2_100.tavg1_2d_aer_Nx.19791228.nc4.nc4?
# Retrying in 10 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXAER.5.12.4/1979/12/MERRA2_100.tavg1_2d_aer_Nx.19791228.nc4.nc4?
# Retrying in 30 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXAER.5.12.4/1979/12/MERRA2_100.tavg1_2d_aer_Nx.19791228.nc4.nc4?
# Retrying in 60 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXAER.5.12.4/1979/12/MERRA2_100.tavg1_2d_aer_Nx.19791228.nc4.nc4?
# Retrying in 180 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXAER.5.12.4/1979/12/MERRA2_100.tavg1_2d_aer_Nx.19791228.nc4.nc4?
# Retrying in 300 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXAER.5.12.4/1979/12/MERRA2_100.tavg1_2d_aer_Nx.19791228.nc4.nc4?
# WARNING: Failed to download https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXAER.5.12.4/1979/12/MERRA2_100.tavg1_2d_aer_Nx.19791228.nc4.nc4?
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXCHM.5.12.4/1979/12/MERRA2_100.tavg1_2d_chm_Nx.19791228.nc4.nc4?
# Retrying in 10 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXCHM.5.12.4/1979/12/MERRA2_100.tavg1_2d_chm_Nx.19791228.nc4.nc4?
# Retrying in 30 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXCHM.5.12.4/1979/12/MERRA2_100.tavg1_2d_chm_Nx.19791228.nc4.nc4?
# Retrying in 60 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXCHM.5.12.4/1979/12/MERRA2_100.tavg1_2d_chm_Nx.19791228.nc4.nc4?
# Retrying in 180 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXCHM.5.12.4/1979/12/MERRA2_100.tavg1_2d_chm_Nx.19791228.nc4.nc4?
# Retrying in 300 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXCHM.5.12.4/1979/12/MERRA2_100.tavg1_2d_chm_Nx.19791228.nc4.nc4?
# WARNING: Failed to download https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXCHM.5.12.4/1979/12/MERRA2_100.tavg1_2d_chm_Nx.19791228.nc4.nc4?
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2I1NXLFO.5.12.4/1979/12/MERRA2_100.inst1_2d_lfo_Nx.19791228.nc4.nc4?
# Retrying in 10 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2I1NXLFO.5.12.4/1979/12/MERRA2_100.inst1_2d_lfo_Nx.19791228.nc4.nc4?
# Retrying in 30 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2I1NXLFO.5.12.4/1979/12/MERRA2_100.inst1_2d_lfo_Nx.19791228.nc4.nc4?
# Retrying in 60 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2I1NXLFO.5.12.4/1979/12/MERRA2_100.inst1_2d_lfo_Nx.19791228.nc4.nc4?
# Retrying in 180 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2I1NXLFO.5.12.4/1979/12/MERRA2_100.inst1_2d_lfo_Nx.19791228.nc4.nc4?
# Retrying in 300 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2I1NXLFO.5.12.4/1979/12/MERRA2_100.inst1_2d_lfo_Nx.19791228.nc4.nc4?
# WARNING: Failed to download https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2I1NXLFO.5.12.4/1979/12/MERRA2_100.inst1_2d_lfo_Nx.19791228.nc4.nc4?
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXFLX.5.12.4/1979/12/MERRA2_100.tavg1_2d_flx_Nx.19791228.nc4.nc4?
# Retrying in 10 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXFLX.5.12.4/1979/12/MERRA2_100.tavg1_2d_flx_Nx.19791228.nc4.nc4?
# Retrying in 30 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXFLX.5.12.4/1979/12/MERRA2_100.tavg1_2d_flx_Nx.19791228.nc4.nc4?
# Retrying in 60 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXFLX.5.12.4/1979/12/MERRA2_100.tavg1_2d_flx_Nx.19791228.nc4.nc4?
# Retrying in 180 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXFLX.5.12.4/1979/12/MERRA2_100.tavg1_2d_flx_Nx.19791228.nc4.nc4?
# Retrying in 300 seconds...
# Processing days:   0%|          | 1/10845 [49:38<8972:43:43, 2978.77s/it]
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXFLX.5.12.4/1979/12/MERRA2_100.tavg1_2d_flx_Nx.19791228.nc4.nc4?
# WARNING: Failed to download https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXFLX.5.12.4/1979/12/MERRA2_100.tavg1_2d_flx_Nx.19791228.nc4.nc4?
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2I1NXINT.5.12.4/1979/12/MERRA2_100.inst1_2d_int_Nx.19791229.nc4.nc4?
# Retrying in 10 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2I1NXINT.5.12.4/1979/12/MERRA2_100.inst1_2d_int_Nx.19791229.nc4.nc4?
# Retrying in 30 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2I1NXINT.5.12.4/1979/12/MERRA2_100.inst1_2d_int_Nx.19791229.nc4.nc4?
# Retrying in 60 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2I1NXINT.5.12.4/1979/12/MERRA2_100.inst1_2d_int_Nx.19791229.nc4.nc4?
# Retrying in 180 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2I1NXINT.5.12.4/1979/12/MERRA2_100.inst1_2d_int_Nx.19791229.nc4.nc4?
# Retrying in 300 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2I1NXINT.5.12.4/1979/12/MERRA2_100.inst1_2d_int_Nx.19791229.nc4.nc4?
# WARNING: Failed to download https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2I1NXINT.5.12.4/1979/12/MERRA2_100.inst1_2d_int_Nx.19791229.nc4.nc4?
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXAER.5.12.4/1979/12/MERRA2_100.tavg1_2d_aer_Nx.19791229.nc4.nc4?
# Retrying in 10 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXAER.5.12.4/1979/12/MERRA2_100.tavg1_2d_aer_Nx.19791229.nc4.nc4?
# Retrying in 30 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXAER.5.12.4/1979/12/MERRA2_100.tavg1_2d_aer_Nx.19791229.nc4.nc4?
# Retrying in 60 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXAER.5.12.4/1979/12/MERRA2_100.tavg1_2d_aer_Nx.19791229.nc4.nc4?
# Retrying in 180 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXAER.5.12.4/1979/12/MERRA2_100.tavg1_2d_aer_Nx.19791229.nc4.nc4?
# Retrying in 300 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXAER.5.12.4/1979/12/MERRA2_100.tavg1_2d_aer_Nx.19791229.nc4.nc4?
# WARNING: Failed to download https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXAER.5.12.4/1979/12/MERRA2_100.tavg1_2d_aer_Nx.19791229.nc4.nc4?
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXCHM.5.12.4/1979/12/MERRA2_100.tavg1_2d_chm_Nx.19791229.nc4.nc4?
# Retrying in 10 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXCHM.5.12.4/1979/12/MERRA2_100.tavg1_2d_chm_Nx.19791229.nc4.nc4?
# Retrying in 30 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXCHM.5.12.4/1979/12/MERRA2_100.tavg1_2d_chm_Nx.19791229.nc4.nc4?
# Retrying in 60 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXCHM.5.12.4/1979/12/MERRA2_100.tavg1_2d_chm_Nx.19791229.nc4.nc4?
# Retrying in 180 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXCHM.5.12.4/1979/12/MERRA2_100.tavg1_2d_chm_Nx.19791229.nc4.nc4?
# Retrying in 300 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXCHM.5.12.4/1979/12/MERRA2_100.tavg1_2d_chm_Nx.19791229.nc4.nc4?
# WARNING: Failed to download https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXCHM.5.12.4/1979/12/MERRA2_100.tavg1_2d_chm_Nx.19791229.nc4.nc4?
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2I1NXLFO.5.12.4/1979/12/MERRA2_100.inst1_2d_lfo_Nx.19791229.nc4.nc4?
# Retrying in 10 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2I1NXLFO.5.12.4/1979/12/MERRA2_100.inst1_2d_lfo_Nx.19791229.nc4.nc4?
# Retrying in 30 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2I1NXLFO.5.12.4/1979/12/MERRA2_100.inst1_2d_lfo_Nx.19791229.nc4.nc4?
# Retrying in 60 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2I1NXLFO.5.12.4/1979/12/MERRA2_100.inst1_2d_lfo_Nx.19791229.nc4.nc4?
# Retrying in 180 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2I1NXLFO.5.12.4/1979/12/MERRA2_100.inst1_2d_lfo_Nx.19791229.nc4.nc4?
# Retrying in 300 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2I1NXLFO.5.12.4/1979/12/MERRA2_100.inst1_2d_lfo_Nx.19791229.nc4.nc4?
# WARNING: Failed to download https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2I1NXLFO.5.12.4/1979/12/MERRA2_100.inst1_2d_lfo_Nx.19791229.nc4.nc4?
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXFLX.5.12.4/1979/12/MERRA2_100.tavg1_2d_flx_Nx.19791229.nc4.nc4?
# Retrying in 10 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXFLX.5.12.4/1979/12/MERRA2_100.tavg1_2d_flx_Nx.19791229.nc4.nc4?
# Retrying in 30 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXFLX.5.12.4/1979/12/MERRA2_100.tavg1_2d_flx_Nx.19791229.nc4.nc4?
# Retrying in 60 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXFLX.5.12.4/1979/12/MERRA2_100.tavg1_2d_flx_Nx.19791229.nc4.nc4?
# Retrying in 180 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXFLX.5.12.4/1979/12/MERRA2_100.tavg1_2d_flx_Nx.19791229.nc4.nc4?
# Retrying in 300 seconds...
# Processing days:   0%|          | 2/10845 [1:39:13<8965:21:10, 2976.60s/it]
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXFLX.5.12.4/1979/12/MERRA2_100.tavg1_2d_flx_Nx.19791229.nc4.nc4?
# WARNING: Failed to download https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXFLX.5.12.4/1979/12/MERRA2_100.tavg1_2d_flx_Nx.19791229.nc4.nc4?
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2I1NXINT.5.12.4/1979/12/MERRA2_100.inst1_2d_int_Nx.19791230.nc4.nc4?
# Retrying in 10 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2I1NXINT.5.12.4/1979/12/MERRA2_100.inst1_2d_int_Nx.19791230.nc4.nc4?
# Retrying in 30 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2I1NXINT.5.12.4/1979/12/MERRA2_100.inst1_2d_int_Nx.19791230.nc4.nc4?
# Retrying in 60 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2I1NXINT.5.12.4/1979/12/MERRA2_100.inst1_2d_int_Nx.19791230.nc4.nc4?
# Retrying in 180 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2I1NXINT.5.12.4/1979/12/MERRA2_100.inst1_2d_int_Nx.19791230.nc4.nc4?
# Retrying in 300 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2I1NXINT.5.12.4/1979/12/MERRA2_100.inst1_2d_int_Nx.19791230.nc4.nc4?
# WARNING: Failed to download https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2I1NXINT.5.12.4/1979/12/MERRA2_100.inst1_2d_int_Nx.19791230.nc4.nc4?
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXAER.5.12.4/1979/12/MERRA2_100.tavg1_2d_aer_Nx.19791230.nc4.nc4?
# Retrying in 10 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXAER.5.12.4/1979/12/MERRA2_100.tavg1_2d_aer_Nx.19791230.nc4.nc4?
# Retrying in 30 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXAER.5.12.4/1979/12/MERRA2_100.tavg1_2d_aer_Nx.19791230.nc4.nc4?
# Retrying in 60 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXAER.5.12.4/1979/12/MERRA2_100.tavg1_2d_aer_Nx.19791230.nc4.nc4?
# Retrying in 180 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXAER.5.12.4/1979/12/MERRA2_100.tavg1_2d_aer_Nx.19791230.nc4.nc4?
# Retrying in 300 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXAER.5.12.4/1979/12/MERRA2_100.tavg1_2d_aer_Nx.19791230.nc4.nc4?
# WARNING: Failed to download https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXAER.5.12.4/1979/12/MERRA2_100.tavg1_2d_aer_Nx.19791230.nc4.nc4?
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXCHM.5.12.4/1979/12/MERRA2_100.tavg1_2d_chm_Nx.19791230.nc4.nc4?
# Retrying in 10 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXCHM.5.12.4/1979/12/MERRA2_100.tavg1_2d_chm_Nx.19791230.nc4.nc4?
# Retrying in 30 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXCHM.5.12.4/1979/12/MERRA2_100.tavg1_2d_chm_Nx.19791230.nc4.nc4?
# Retrying in 60 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXCHM.5.12.4/1979/12/MERRA2_100.tavg1_2d_chm_Nx.19791230.nc4.nc4?
# Retrying in 180 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXCHM.5.12.4/1979/12/MERRA2_100.tavg1_2d_chm_Nx.19791230.nc4.nc4?
# Retrying in 300 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXCHM.5.12.4/1979/12/MERRA2_100.tavg1_2d_chm_Nx.19791230.nc4.nc4?
# WARNING: Failed to download https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXCHM.5.12.4/1979/12/MERRA2_100.tavg1_2d_chm_Nx.19791230.nc4.nc4?
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2I1NXLFO.5.12.4/1979/12/MERRA2_100.inst1_2d_lfo_Nx.19791230.nc4.nc4?
# Retrying in 10 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2I1NXLFO.5.12.4/1979/12/MERRA2_100.inst1_2d_lfo_Nx.19791230.nc4.nc4?
# Retrying in 30 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2I1NXLFO.5.12.4/1979/12/MERRA2_100.inst1_2d_lfo_Nx.19791230.nc4.nc4?
# Retrying in 60 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2I1NXLFO.5.12.4/1979/12/MERRA2_100.inst1_2d_lfo_Nx.19791230.nc4.nc4?
# Retrying in 180 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2I1NXLFO.5.12.4/1979/12/MERRA2_100.inst1_2d_lfo_Nx.19791230.nc4.nc4?
# Retrying in 300 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2I1NXLFO.5.12.4/1979/12/MERRA2_100.inst1_2d_lfo_Nx.19791230.nc4.nc4?
# WARNING: Failed to download https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2I1NXLFO.5.12.4/1979/12/MERRA2_100.inst1_2d_lfo_Nx.19791230.nc4.nc4?
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXFLX.5.12.4/1979/12/MERRA2_100.tavg1_2d_flx_Nx.19791230.nc4.nc4?
# Retrying in 10 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXFLX.5.12.4/1979/12/MERRA2_100.tavg1_2d_flx_Nx.19791230.nc4.nc4?
# Retrying in 30 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXFLX.5.12.4/1979/12/MERRA2_100.tavg1_2d_flx_Nx.19791230.nc4.nc4?
# Retrying in 60 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXFLX.5.12.4/1979/12/MERRA2_100.tavg1_2d_flx_Nx.19791230.nc4.nc4?
# Retrying in 180 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXFLX.5.12.4/1979/12/MERRA2_100.tavg1_2d_flx_Nx.19791230.nc4.nc4?
# Retrying in 300 seconds...
# Processing days:   0%|          | 3/10845 [2:28:58<8974:54:57, 2980.05s/it]
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXFLX.5.12.4/1979/12/MERRA2_100.tavg1_2d_flx_Nx.19791230.nc4.nc4?
# WARNING: Failed to download https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXFLX.5.12.4/1979/12/MERRA2_100.tavg1_2d_flx_Nx.19791230.nc4.nc4?
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2I1NXINT.5.12.4/1979/12/MERRA2_100.inst1_2d_int_Nx.19791231.nc4.nc4?
# Retrying in 10 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2I1NXINT.5.12.4/1979/12/MERRA2_100.inst1_2d_int_Nx.19791231.nc4.nc4?
# Retrying in 30 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2I1NXINT.5.12.4/1979/12/MERRA2_100.inst1_2d_int_Nx.19791231.nc4.nc4?
# Retrying in 60 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2I1NXINT.5.12.4/1979/12/MERRA2_100.inst1_2d_int_Nx.19791231.nc4.nc4?
# Retrying in 180 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2I1NXINT.5.12.4/1979/12/MERRA2_100.inst1_2d_int_Nx.19791231.nc4.nc4?
# Retrying in 300 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2I1NXINT.5.12.4/1979/12/MERRA2_100.inst1_2d_int_Nx.19791231.nc4.nc4?
# WARNING: Failed to download https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2I1NXINT.5.12.4/1979/12/MERRA2_100.inst1_2d_int_Nx.19791231.nc4.nc4?
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXAER.5.12.4/1979/12/MERRA2_100.tavg1_2d_aer_Nx.19791231.nc4.nc4?
# Retrying in 10 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXAER.5.12.4/1979/12/MERRA2_100.tavg1_2d_aer_Nx.19791231.nc4.nc4?
# Retrying in 30 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXAER.5.12.4/1979/12/MERRA2_100.tavg1_2d_aer_Nx.19791231.nc4.nc4?
# Retrying in 60 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXAER.5.12.4/1979/12/MERRA2_100.tavg1_2d_aer_Nx.19791231.nc4.nc4?
# Retrying in 180 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXAER.5.12.4/1979/12/MERRA2_100.tavg1_2d_aer_Nx.19791231.nc4.nc4?
# Retrying in 300 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXAER.5.12.4/1979/12/MERRA2_100.tavg1_2d_aer_Nx.19791231.nc4.nc4?
# WARNING: Failed to download https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXAER.5.12.4/1979/12/MERRA2_100.tavg1_2d_aer_Nx.19791231.nc4.nc4?
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXCHM.5.12.4/1979/12/MERRA2_100.tavg1_2d_chm_Nx.19791231.nc4.nc4?
# Retrying in 10 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXCHM.5.12.4/1979/12/MERRA2_100.tavg1_2d_chm_Nx.19791231.nc4.nc4?
# Retrying in 30 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXCHM.5.12.4/1979/12/MERRA2_100.tavg1_2d_chm_Nx.19791231.nc4.nc4?
# Retrying in 60 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXCHM.5.12.4/1979/12/MERRA2_100.tavg1_2d_chm_Nx.19791231.nc4.nc4?
# Retrying in 180 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXCHM.5.12.4/1979/12/MERRA2_100.tavg1_2d_chm_Nx.19791231.nc4.nc4?
# Retrying in 300 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXCHM.5.12.4/1979/12/MERRA2_100.tavg1_2d_chm_Nx.19791231.nc4.nc4?
# WARNING: Failed to download https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXCHM.5.12.4/1979/12/MERRA2_100.tavg1_2d_chm_Nx.19791231.nc4.nc4?
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2I1NXLFO.5.12.4/1979/12/MERRA2_100.inst1_2d_lfo_Nx.19791231.nc4.nc4?
# Retrying in 10 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2I1NXLFO.5.12.4/1979/12/MERRA2_100.inst1_2d_lfo_Nx.19791231.nc4.nc4?
# Retrying in 30 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2I1NXLFO.5.12.4/1979/12/MERRA2_100.inst1_2d_lfo_Nx.19791231.nc4.nc4?
# Retrying in 60 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2I1NXLFO.5.12.4/1979/12/MERRA2_100.inst1_2d_lfo_Nx.19791231.nc4.nc4?
# Retrying in 180 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2I1NXLFO.5.12.4/1979/12/MERRA2_100.inst1_2d_lfo_Nx.19791231.nc4.nc4?
# Retrying in 300 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2I1NXLFO.5.12.4/1979/12/MERRA2_100.inst1_2d_lfo_Nx.19791231.nc4.nc4?
# WARNING: Failed to download https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2I1NXLFO.5.12.4/1979/12/MERRA2_100.inst1_2d_lfo_Nx.19791231.nc4.nc4?
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXFLX.5.12.4/1979/12/MERRA2_100.tavg1_2d_flx_Nx.19791231.nc4.nc4?
# Retrying in 10 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXFLX.5.12.4/1979/12/MERRA2_100.tavg1_2d_flx_Nx.19791231.nc4.nc4?
# Retrying in 30 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXFLX.5.12.4/1979/12/MERRA2_100.tavg1_2d_flx_Nx.19791231.nc4.nc4?
# Retrying in 60 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXFLX.5.12.4/1979/12/MERRA2_100.tavg1_2d_flx_Nx.19791231.nc4.nc4?
# Retrying in 180 seconds...
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXFLX.5.12.4/1979/12/MERRA2_100.tavg1_2d_flx_Nx.19791231.nc4.nc4?
# Retrying in 300 seconds...
# Processing days:   0%|          | 4/10845 [3:18:33<8968:12:26, 2978.10s/it]
# HTTP 404 for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXFLX.5.12.4/1979/12/MERRA2_100.tavg1_2d_flx_Nx.19791231.nc4.nc4?
# WARNING: Failed to download https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXFLX.5.12.4/1979/12/MERRA2_100.tavg1_2d_flx_Nx.19791231.nc4.nc4?
# Processing days:   5%|▍         | 489/10845 [27:48:21<609:54:27, 212.02s/it]
# Attempt 1/6 failed for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXFLX.5.12.4/1982/01/MERRA2_100.tavg1_2d_flx_Nx.19820103.nc4.nc4?. Error: HTTPSConnectionPool(host='goldsmr4.gesdisc.eosdis.nasa.gov', port=443): Read timed out. (read timeout=60)
# Retrying in 10 seconds...
# Attempt 2/6 failed for https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/hyrax/MERRA2/M2T1NXFLX.5.12.4/1982/01/MERRA2_100.tavg1_2d_flx_Nx.19820103.nc4.nc4?. Error: HTTPSConnectionPool(host='goldsmr4.gesdisc.eosdis.nasa.gov', port=443): Max retries exceeded with url: /opendap/hyrax/MERRA2/M2T1NXFLX.5.12.4/1982/01/MERRA2_100.tavg1_2d_flx_Nx.19820103.nc4.nc4 (Caused by NewConnectionError("<urllib3.connection.HTTPSConnection object at 0x000001C7F4F49D90>: Failed to establish a new connection: [WinError 10060] Impossibile stabilire la connessione. Risposta non corretta della parte connessa dopo l'intervallo di tempo oppure mancata risposta dall'host collegato"))
# Retrying in 30 seconds...
# Processing days:  24%|██▍       | 2590/10845 [143:04:33<469:29:49, 204.75s/it]

# %% [markdown]
# ## Ionosphere data
# In this session, the magnetic data from Swarm three-identical satellites are pre-processed.
#
# Data must be downloaded from ESA's ftp dissemination service, which requires a free EO user account (you can create one here: https://eoiam-idp.eo.esa.int/) and placed in one folder of your computer were the VRE is running.
#
# In the following example the data are inside the folder **ndir** = `E:\Swarm_data`, but **remember to replace with your own data path**
# The ESA Swarm file names appear as:
# SW_OPER_MAGA_LR_1B_20131125T110252_20131125T235959_0602_MDR_MAG_LR.cdf
# SW_OPER_MAGA_LR_1B_20201027T134456_20201027T150128_0605_MDR_MAG_LR.cdf
# ...
# SW_OPER_MAGC_LR_1B_20140524T000000_20140524T235959_0602_MDR_MAG_LR.cdf
#
#
# The first part of the following code selects the data in the time range defined for the analysis of the earthquake.

# %%
# --- 1. User Configuration & Parameters ---

# Set your Vires token here.
# You will be prompted to enter the token in the console the first time.
# Information on how to get a token: https://viresclient.readthedocs.io/en/latest/access_token.html
viresclient.set_token("https://vires.services/ows")

# --- 2. Calculation of Time and Space Windows ---

# Build the main datetime object for the earthquake
eq_time =datetime(EQ_year, EQ_month, EQ_day, EQ_hour, EQ_minute, EQ_second)

# Define the start and end times for the data request
time_start = eq_time - timedelta(days=day_before)
time_end = eq_time + timedelta(days=day_after)

# Calculate the preparatory radius based on Dobrovolsky's formula (in degrees)
# This defines the primary area of interest around the epicenter.
radius_dobrovolsky = 10**(0.43 * EQ_mag) / 111

# Define a broader longitude bounding box for the initial data request
# We add a buffer to ensure we capture complete satellite tracks passing near the area.
lon_buffer = 5.0
min_lon = EPILON - radius_dobrovolsky - lon_buffer
max_lon = EPILON + radius_dobrovolsky + lon_buffer

print(f"Requesting data from {time_start.strftime('%Y-%m-%d')} to {time_end.strftime('%Y-%m-%d')}")
print(f"Spatial filter (longitude): {min_lon:.2f} to {max_lon:.2f}")


def dat_orden_alpha(x, SAT):
    Mmlat = 70  # Maximum latitude
    sat_map = {'A': 1, 'B': 2, 'C': 3, 'S': 4}
    sat = sat_map.get(SAT, 0)
    # Filter by latitude (column 7 → index 6 zero‑based)
    y = x[np.abs(x[:, 6]) <= Mmlat]
    nn = y.shape[0]
    if nn <= 1:
        return np.empty((0, x.shape[1] + 2))
    yn = np.zeros((nn - 1, x.shape[1] + 2))  # Two additional columns: sat and track number
    m = 1  # track number
    for k in range(nn - 1):
        row = np.concatenate([[sat], y[k, 0:6], [m], y[k, 6:]])  # Two extra columns: sat and track number
        yn[k, :] = row
        # Track‑change condition
        if abs(y[k, 6] - y[k + 1, 6]) > 0.5 or abs(y[k, 7] - y[k + 1, 7]) > 1:
            m += 1
    return yn

# --- 3. Viresclient Data Request ---

print("Connecting to Vires server and downloading data...")
request = viresclient.SwarmRequest()

# Set the collection for all three Swarm satellites (A, B, C)
request.set_collection("SW_OPER_MAGA_LR_1B", "SW_OPER_MAGB_LR_1B", "SW_OPER_MAGC_LR_1B")

# Define the specific data products to fetch
request.set_products(
    measurements=["B_NEC", "F", "Flags_F", "Flags_B", "Flags_q", "Flags_Platform"],
    sampling_step="PT1S" # Resample to 1-second intervals
)

# Apply the spatial filter on the server to reduce download size
request.set_range_filter('Longitude', min_lon, max_lon)

# Execute the data fetching for the specified time interval
data = request.get_between(
    start_time=time_start,
    end_time=time_end
)

# Load the downloaded data into an xarray.Dataset for easy manipulation
ds = data.as_xarray()
print("Download complete.")


# --- 4. Setup Output Directory ---
output_dir = os.path.join('data', 'Swarm_tracks')
os.makedirs(output_dir, exist_ok=True)
print(f"Output files will be saved in: {output_dir}")


# --- 5. Data Processing & Saving ---
print("Processing downloaded data and saving tracks...")
total_files_saved = 0

# The downloaded dataset contains data from all satellites mixed together.
# We group the data by the 'Spacecraft' identifier ('A', 'B', 'C') to process each one.
for sat_id, ds_sat in ds.groupby('Spacecraft'):
    print(f"  - Processing tracks for Swarm satellite {sat_id}")

    # Check if this satellite group has any data
    if ds_sat.sizes['Timestamp'] == 0:
        print(f"  - No data for satellite {sat_id} in the given window.")
        continue

    # Convert timestamp to a pandas DatetimeIndex for easy component extraction
    times = pd.to_datetime(ds_sat['Timestamp'].values)

    # Reconstruct the numpy array format required by the 'dat_orden_alpha' function
    # This structure matches the one expected from the original CDF file reading script.
    # Columns: 0-5:Time, 6:Lat, 7:Lon, 8:Radius, 9-12:Flags, 13-15:B_NEC, 16:F
    n = len(times)
    x = np.empty((n, 17), dtype=float)
    x[:, 0] = times.year
    x[:, 1] = times.month
    x[:, 2] = times.day
    x[:, 3] = times.hour
    x[:, 4] = times.minute
    x[:, 5] = times.second + times.microsecond / 1e6
    x[:, 6] = ds_sat['Latitude'].values
    x[:, 7] = ds_sat['Longitude'].values
    x[:, 8] = ds_sat['Radius'].values
    x[:, 9] = ds_sat['Flags_F'].values
    x[:, 10] = ds_sat['Flags_B'].values
    x[:, 11] = ds_sat['Flags_q'].values
    x[:, 12] = ds_sat['Flags_Platform'].values
    x[:, 13:16] = ds_sat['B_NEC'].values
    x[:, 16] = ds_sat['F'].values

    # Identify and number the satellite tracks
    yn = dat_orden_alpha(x, sat_id)

    # Apply a final, more precise spatial filter based on the Dobrovolsky radius.
    # A generous 15-degree buffer is added.
    # The longitude is now in column 9 of the 'yn' array.
    mask = np.abs(yn[:, 9] - EPILON) <= (radius_dobrovolsky + 15.0)
    y_sel = yn[mask]

    if y_sel.shape[0] > 0:
        print(f"  - Found {y_sel.shape[0]} data points for satellite {sat_id} passing the filter.")

        # Group data by day and save one file per day.
        # The date columns are at indices 1 (Year), 2 (Month), 3 (Day) in the processed 'yn' array.
        # Create a unique integer for each date (e.g., 20160824) to group the data rows.
        dates_int = (y_sel[:, 1] * 10000 + y_sel[:, 2] * 100 + y_sel[:, 3]).astype(int)
        unique_dates = np.unique(dates_int)

        print(f"  - Grouping data into {len(unique_dates)} daily files for satellite {sat_id}.")

        for date_val in unique_dates:
            # Select all data points for the current day
            day_mask = (dates_int == date_val)
            current_day_data = y_sel[day_mask]

            # Count the number of unique tracks in the current day's data
            # The track number is in the 8th column (index 8)
            num_tracks_in_file = len(np.unique(current_day_data[:, 8]))

            # Extract year, month, day from the integer value for the filename
            year = date_val // 10000
            month = (date_val % 10000) // 100
            day = date_val % 100

            # Format the filename to include the date
            filename = f"Swarm_tracks_{year:04d}{month:02d}{day:02d}_{sat_id}.mat"
            filepath = os.path.join(output_dir, filename)

            # Save the current day's track data and the track count
            savemat(filepath, {
                "y": current_day_data
            })
            print(f"    - Saved {filename} containing {num_tracks_in_file} track(s).")
            total_files_saved += 1
    else:
        print(f"  - No tracks passed the final spatial filter for satellite {sat_id}.")

print(f"\nProcessing complete. Total files saved: {total_files_saved}")
# Out:
# Setting access token for https://vires.services/ows...<br>Generate a token at <a href="https://vires.services/accounts/tokens/">https://vires.services/accounts/tokens/</a>
# Token saved for https://vires.services/ows
# Requesting data from 2015-12-28 to 2016-08-24
# Spatial filter (longitude): 2.61 to 23.85
# Connecting to Vires server and downloading data...
#           |  [ Elapsed: 00:00, Remaining: ?]
# Processing:    0%|          |  [ Elapsed: 00:00, Remaining: ? ] [1/5]
# Downloading:   0%|          |  [ Elapsed: 00:00, Remaining: ? ] (53.362MB)
# Processing:    0%|          |  [ Elapsed: 00:00, Remaining: ? ] [2/5]
# Downloading:   0%|          |  [ Elapsed: 00:00, Remaining: ? ] (53.18MB)
# Processing:    0%|          |  [ Elapsed: 00:00, Remaining: ? ] [3/5]
# Downloading:   0%|          |  [ Elapsed: 00:00, Remaining: ? ] (52.982MB)
# Processing:    0%|          |  [ Elapsed: 00:00, Remaining: ? ] [4/5]
# Downloading:   0%|          |  [ Elapsed: 00:00, Remaining: ? ] (53.729MB)
# Processing:    0%|          |  [ Elapsed: 00:00, Remaining: ? ] [5/5]
# Downloading:   0%|          |  [ Elapsed: 00:00, Remaining: ? ] (42.995MB)

# %% [markdown]
# ## Geomagnetic indexes
# The following cells are necessary to update the geomagnetic indexes Dst and ap files.
# *Please, note that is not necessary to update these files for new case studies except it requires more recent data not previously stored in the same files.
# ### Updating the Dst geomagnetic index

# %%
import numpy as np
import requests
import datetime
import sys


def parse_dst_data_from_html(html_content):
    """
    Extracts Dst data from the raw HTML content of the web page.

    Args:
        html_content (str): The text content of the HTML page.

    Returns:
        list: A list of lists, where each inner list represents a row of numeric data.
              Returns an empty list if the data cannot be found.
    """
    try:
        # Find the start of the data table by searching for the "DAY" header
        start_index = html_content.find('DAY')
        if start_index == -1:
            return []

        # Find the end of the data table (usually before the </pre> tag)
        end_index = html_content.find('</pre>', start_index)
        if end_index == -1:
            return []

        # Extract the text block containing only the data
        data_block = html_content[start_index:end_index]
        # Split the block into lines, skipping the header
        lines = data_block.strip().split('\n')[1:]
        
        # Define the specific character slices for each of the 24 hourly values
        HOURLY_SLICES = [
            (3, 7), (7, 11), (11, 15), (15, 19), (19, 23),
            (23, 27), (27, 31), (31, 35), (36, 40), (40, 44), (44, 48),
            (48, 52), (52, 56), (56, 60), (60, 64), (64, 68), (69, 73),
            (73, 77), (77, 81), (81, 85), (85, 89), (89, 93), (93, 97), (97, 101)
        ]
        
        parsed_data = []
        for line in lines:
            if not line.strip():
                continue

            try:
                # 1. Isolate the day number (first 2 chars) and the hourly data string
                day_str = line[0:3].strip()
                hourly_data_str = line[:]

                # 2. Initialize the 'parts' list with the day number
                parts = [int(day_str)]

                # 3. Loop through the *specific* slices, not a regular pattern
                for start, end in HOURLY_SLICES:
                    chunk = hourly_data_str[start:end]
                    value = int(chunk.strip())
                    parts.append(value)

                # 4. A valid row should have 1 day + 24 hours = 25 values
                if len(parts) == 25:
                    parsed_data.append(parts)
                else:
                    print(f"Warning: Skipped line for day {day_str}. Parsed {len(parts) - 1}/24 values.")

            except (ValueError, IndexError) as e:
                # print(f"Warning: Skipped line due to a data format error: {line} -> Error: {e}")
                continue

    except Exception as e:
        print(f"Unexpected error during HTML parsing: {e}")
        return []

    return parsed_data

def aggiorna_dst_to_final():
    """
    Downloads and updates the Dst (Disturbance storm time) index data
    from the World Data Center for Geomagnetism, Kyoto.
    """
    output_filename = 'data/dst_index2.dat'

    # 1. Load existing data
    try:
        idst_old = np.loadtxt(output_filename, dtype=int)
        print(f"Loaded {idst_old.shape[0]} existing records from '{output_filename}'.")
    except FileNotFoundError:
        print(f"File '{output_filename}' not found. Starting with an empty dataset.")
        # Create an empty array with the correct number of columns (27: year, month, day, 24 hourly values)
        idst_old = np.empty((0, 27), dtype=int)
    except Exception as e:
        print(f"Error reading file '{output_filename}': {e}")
        return

    # Get the current year for the loop's upper limit
    current_year = datetime.datetime.now().year

    # The data types to download, in order of priority (final overwrites provisional, etc.)
    data_sources = ['dst_final', 'dst_provisional', 'dst_realtime']
    base_url = 'https://wdc.kugi.kyoto-u.ac.jp'

    # 2. Loop to download and update data
    for data_type in data_sources:
        print(f"\n--- Starting processing for data type: {data_type} ---")
        for year in range(2000, current_year + 1):
            # Show a progress indicator
            sys.stdout.write(f"Processing Year: {year}\r")
            sys.stdout.flush()

            for month in range(1, 13):
                # Build the URL
                url = f"{base_url}/{data_type}/{year}{month:02d}/index.html"
                
                try:
                    # Perform the web request
                    response = requests.get(url, timeout=10)
                    # Check if the request was successful
                    if response.status_code == 200:
                        # Parse data from the HTML
                        monthly_data = parse_dst_data_from_html(response.text)

                        if not monthly_data:
                            continue

                        # Update the numpy array with the new data
                        for day_data in monthly_data:
                            day = day_data[0]
                            # Create the complete row with year and month
                            new_row = np.array([year, month] + day_data, dtype=int)

                            # Check if a row for this date already exists
                            existing_row_index = np.where(
                                (idst_old[:, 0] == year) &
                                (idst_old[:, 1] == month) &
                                (idst_old[:, 2] == day)
                            )[0]

                            if existing_row_index.size == 0:
                                # The row does not exist, so add it
                                idst_old = np.vstack([idst_old, new_row])
                            else:
                                # The row exists, update it if it's different
                                idx = existing_row_index[0]
                                if not np.array_equal(idst_old[idx], new_row):
                                    idst_old[idx] = new_row

                except requests.exceptions.RequestException:
                    # If the URL is not found (e.g., for future months), ignore the error
                    pass

    print("\nDownload and update completed.")

    # 3. Filter and sort the data
    if idst_old.shape[0] > 0:
        # Remove rows where any of the hourly values is 9999
        # The hourly data columns range from index 3 to the end
        original_rows = idst_old.shape[0]
        idst_old = idst_old[np.all(idst_old[:, 3:] != 9999, axis=1)]
        rows_removed = original_rows - idst_old.shape[0]
        if rows_removed > 0:
            print(f"Removed {rows_removed} rows containing 9999 values.")

        # Sort the array by year, month, and day
        # np.lexsort sorts using keys from last to first
        indices = np.lexsort((idst_old[:, 2], idst_old[:, 1], idst_old[:, 0]))
        idst_old = idst_old[indices]
        print("Data sorted by date.")

    # 4. Save the updated data to the file
    try:
        # The '%d' format ensures all numbers are written as integers
        np.savetxt(output_filename, idst_old, fmt='%d', delimiter=' ')
        print(f"Final data successfully saved to '{output_filename}'. Total records: {idst_old.shape[0]}")
    except Exception as e:
        print(f"Error while saving the file '{output_filename}': {e}")


if __name__ == '__main__':
    aggiorna_dst_to_final()
# Out:
# File 'data/dst_index2.dat' not found. Starting with an empty dataset.
#
# --- Starting processing for data type: dst_final ---
# Processing Year: 2000
# Processing Year: 2025
# --- Starting processing for data type: dst_provisional ---
# Processing Year: 2025
# --- Starting processing for data type: dst_realtime ---
# Processing Year: 2025
# Download and update completed.
# Removed 19 rows containing 9999 values.
# Data sorted by date.
# Final data successfully saved to 'data/dst_index2.dat'. Total records: 9447

# %% [markdown]
# ### Updating the ap geomagnetic index
# The following cell defines a simple function to convert the kp to ap according to standard tables.

# %%
from datetime import datetime
def kp2ap(kp: str) -> Union[int, None]:
    """
    Converts a Kp index string to its corresponding Ap index value.
    This function uses a dictionary for efficient and clean mapping.

    Args:
        kp (str): The Kp index as a string (e.g., "0o", "3-", "5+").

    Returns:
        Union[int, None]: The corresponding Ap index as an integer, or
                          None if the Kp string is not found in the map.
    """
    # A dictionary to map Kp string values to Ap integer values.
    # This is more efficient and readable than a long series of if statements.
    kp_to_ap_map = {
        '0o': 0, '0+': 2, '1-': 3, '1o': 4, '1+': 5,
        '2-': 6, '2o': 7, '2+': 9, '3-': 12, '3o': 15,
        '3+': 18, '4-': 22, '4o': 27, '4+': 32, '5-': 39,
        '5o': 48, '5+': 56, '6-': 67, '6o': 80, '6+': 94,
        '7-': 111, '7o': 132, '7+': 154, '8-': 179, '8o': 207,
        '8+': 236, '9-': 300, '9o': 400
    }
    return kp_to_ap_map.get(kp)


def _parse_gfz_data(data_string: str) -> list:
    """
    Helper function to parse the fixed-width text data from GFZ Potsdam.
    It processes a raw string, extracts data, and converts Kp to Ap values.

    Args:
        data_string (str): The raw text content downloaded from the URL.

    Returns:
        list: A list of lists, where each inner list represents a row of parsed data
              [year, month, day, ap1, ap2, ..., ap8].
    """
    parsed_data = []
    # Split the raw string into individual lines.
    lines = data_string.strip().split('\n')
    for line in lines:
        # Skip header, footer, or empty lines by checking length and first character.
        if len(line) < 33 or not line[0].isdigit():
            continue

        try:
            # Extract date components by slicing the string.
            year = 2000 + int(line[0:2])
            month = int(line[2:4])
            day = int(line[4:6])

            # Extract the 8 Kp values and convert them to Ap values using the helper.
            ap_values = [
                kp2ap(line[8:10]),
                kp2ap(line[11:13]),
                kp2ap(line[14:16]),
                kp2ap(line[17:19]),
                kp2ap(line[21:23]),
                kp2ap(line[24:26]),
                kp2ap(line[27:29]),
                kp2ap(line[30:32]),
            ]

            # If any Kp conversion failed, skip this line to avoid corrupt data.
            if any(ap is None for ap in ap_values):
                print(f"Warning: Skipping line with invalid Kp value: {line}")
                continue

            # Create the full row [year, month, day, ap_values...] and append it.
            row = [year, month, day] + ap_values
            parsed_data.append(row)
        except (ValueError, IndexError):
            # Handle potential errors if a line is malformed.
            print(f"Warning: Skipping malformed line: {line}")
            continue

    return parsed_data


def update_ap(full_update: bool):
    """
    Main function to update the Ap index data file 'ap_index2.dat'.

    Args:
        full_update (bool):
            If True, it performs a complete update, fetching all definitive data
            from a starting year and overwriting the local file.
            If False, it performs an incremental update, fetching only the
            previous and current months and appending new data to the local file.
    """
    output_filename = 'data/ap_index2.dat'
    iap = []

    # --- FULL UPDATE LOGIC ---
    if full_update:
        print("Starting full update...")
        iap = []  # Reset data for a full update.
        start_year = 2000
        now = datetime.now()
        current_year = now.year
        current_month = now.month

        # Calculate the total number of historical months to fetch.
        # This goes up to two months before the current one, as those are considered definitive.
        total_months = (current_year - start_year) * 12 + current_month - 2

        for month_index in range(1, total_months + 1):
            # Calculate the specific year and month to fetch for this iteration.
            year_to_check = start_year + math.floor((month_index - 1) / 12)
            month_to_check = month_index - (year_to_check - start_year) * 12

            # Format the URL for the historical data FTP server.
            year_str = str(year_to_check)
            url = f"http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp{year_str[2:]}{month_to_check:02d}.tab"

            print(f"Fetching historical data: {url}")
            try:
                # Fetch data from the URL.
                response = requests.get(url, timeout=10)
                response.raise_for_status()  # Raise an exception for HTTP errors (4xx or 5xx).

                # Parse the downloaded text and extend the main data list.
                ap_table = _parse_gfz_data(response.text)
                if ap_table:
                    iap.extend(ap_table)
            except requests.exceptions.RequestException as e:
                print(f"Error fetching {url}: {e}")

    # --- INCREMENTAL UPDATE LOGIC ---
    else:
        print("Starting incremental update...")
        # For incremental updates, we first load the existing local data.
        try:
            # np.loadtxt is a simple way to load space-delimited files.
            iap = np.loadtxt(output_filename, dtype=int).tolist()
        except (IOError, ValueError):  # Handles FileNotFoundError and empty files.
            print(f"Warning: '{output_filename}' not found or empty. Will create a new one.")
            iap = []

    # --- FETCH PREVIOUS AND CURRENT MONTHS (for both update types) ---

    # URL for the previous month's data (preliminary).
    url_prev = 'https://www-app3.gfz-potsdam.de/kp_index/pqlyymm.tab'
    ap_table_prev = []
    print(f"Fetching previous month's data: {url_prev}")
    try:
        response_prev = requests.get(url_prev, timeout=10)
        response_prev.raise_for_status()
        ap_table_prev = _parse_gfz_data(response_prev.text)
    except requests.exceptions.RequestException as e:
        print(f"Error fetching previous month's data: {e}")

    # URL for the current month's data (quicklook).
    url_curr = 'https://www-app3.gfz-potsdam.de/kp_index/qlyymm.tab'
    ap_table_curr = []
    print(f"Fetching current month's data: {url_curr}")
    try:
        response_curr = requests.get(url_curr, timeout=10)
        response_curr.raise_for_status()
        ap_table_curr = _parse_gfz_data(response_curr.text)
    except requests.exceptions.RequestException as e:
        print(f"Error fetching current month's data: {e}")

    # --- COMBINE AND WRITE DATA ---

    if full_update:
        # In a full update, we append the newly fetched preliminary and quicklook data.
        if ap_table_prev:
            iap.extend(ap_table_prev)
        if ap_table_curr:
            iap.extend(ap_table_curr)

        # Overwrite the output file with the complete dataset.
        print(f"Writing complete dataset to '{output_filename}'...")
        with open(output_filename, 'w') as file_output:
            for row in iap:
                # The original script repeats each of the 8 Ap values three times.
                values_to_write = row[:3]
                for val in row[3:]:
                    values_to_write.extend([val, val, val])
                file_output.write(f"{' '.join(map(str, values_to_write))}\n")
    else:
        # In an incremental update, we only append new, unique rows.
        print(f"Appending new data to '{output_filename}'...")
        # Create a set of existing dates for fast lookups to prevent duplicates.
        existing_dates = {(row[0], row[1], row[2]) for row in iap}

        # Combine the previous and current month data.
        new_data = ap_table_prev + ap_table_curr

        rows_to_add = []
        for row in new_data:
            current_date_tuple = (row[0], row[1], row[2])
            if current_date_tuple not in existing_dates:
                rows_to_add.append(row)
                # Add to set to also handle duplicates within the new data itself.
                existing_dates.add(current_date_tuple)

        # Sort data by date before writing to ensure chronological order.
        rows_to_add.sort(key=lambda x: (x[0], x[1], x[2]))

        if rows_to_add:
            # Open the file in append mode to add the new rows.
            with open(output_filename, 'a') as file_output:
                for row in rows_to_add:
                    values_to_write = row[:3]
                    for val in row[3:]:
                        values_to_write.extend([val, val, val])
                    # Add a leading newline for appended entries, just like the original script.
                    # This assumes the file ends with a newline.
                    file_output.write(f"\n{' '.join(map(str, values_to_write))}")
            print(f"Added {len(rows_to_add)} new entries.")
        else:
            print("No new data to add.")

    print("Update process finished.")


# --- EXAMPLE OF HOW TO RUN THE FUNCTION ---
if __name__ == '__main__':
    # To run an incremental update (most common case):
    # This will only add new data to 'ap_index2.dat'.
    update_ap(full_update=True)

    # To run a full update (takes longer and overwrites the file):
    # This will rebuild 'ap_index2.dat' from the year 2000.
    # update_ap(full_update=True)
# Out:
# Starting full update...
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0001.tab
# Warning: Skipping malformed line: 0001                                  Mean 13 0.63
# Warning: Skipping malformed line: 0001 Q 21  17  18   9   8  19K 16  15  10K 25A
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0002.tab
# Warning: Skipping malformed line: 0002                                  Mean 16 0.72
# Warning: Skipping malformed line: 0002 Q 18  19   4  17  20K 22  29A 16A  2A  1A
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0003.tab
# Warning: Skipping malformed line: 0003                                  Mean  9 0.44
# Warning: Skipping malformed line: 0003 Q 15  16  26  27   4  21  28   9  17  13
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0004.tab
# Warning: Skipping malformed line: 0004                                  Mean 15 0.66
# Warning: Skipping malformed line: 0004 Q 26  14  22  18  25  15  23  13K 12A 11A
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0005.tab
# Warning: Skipping malformed line: 0005                                  Mean 15 0.66
# Warning: Skipping malformed line: 0005 Q  8  11  20   7  21  10   4  18A 19A  9A
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0006.tab
# Warning: Skipping malformed line: 0006                                  Mean 15 0.71
# Warning: Skipping malformed line: 0006 Q 30  16   9  25K 17  21K  2  20  19K 29A
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0007.tab
# Warning: Skipping malformed line: 0007                                  Mean 21 0.76
# Warning: Skipping malformed line: 0007 Q  2   7  24   6  25   9   8  21A  1A 27A
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0008.tab
# Warning: Skipping malformed line: 0008                                  Mean 16 0.63
# Warning: Skipping malformed line: 0008 Q 22  25  18  19  26  20   9  17   8  27A
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0009.tab
# Warning: Skipping malformed line: 0009                                  Mean 18 0.76
# Warning: Skipping malformed line: 0009 Q 10  14  11   9  22  23A  3A 29A  5A 13A
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0010.tab
# Warning: Skipping malformed line: 0010                                  Mean 18 0.67
# Warning: Skipping malformed line: 0010 Q 20   8  21   9   6  27   7  25  12K 26A
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0011.tab
# Warning: Skipping malformed line: 0011                                  Mean 17 0.68
# Warning: Skipping malformed line: 0011 Q 17  16  15   3   2  14  18K 30  23  25K
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0012.tab
# Warning: Skipping malformed line: 0012                                  Mean  7 0.36
# Warning: Skipping malformed line: 0012 Q 15  31  14  20  30   2  16  21   5  13
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0101.tab
# Warning: Skipping malformed line: 0101                                  Mean  8 0.42
# Warning: Skipping malformed line: 0101 Q  1  30   6   2  19  18  27   7   5K  9
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0102.tab
# Warning: Skipping malformed line: 0102                                  Mean  7 0.32
# Warning: Skipping malformed line: 0102 Q  3   4  18  25  17  16   5  24  19   9
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0103.tab
# Warning: Skipping malformed line: 0103                                  Mean 20 0.66
# Warning: Skipping malformed line: 0103 Q 15  16  26  11  17  10   1K 25   9   8K
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0104.tab
# Warning: Skipping malformed line: 0104                                  Mean 22 0.85
# Warning: Skipping malformed line: 0104 Q 30  27  24  19  25  26  17  20K  3  21A
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0105.tab
# Warning: Skipping malformed line: 0105                                  Mean 10 0.47
# Warning: Skipping malformed line: 0105 Q 31   5  30  21   1   2  26   6  24  20
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0106.tab
# Warning: Skipping malformed line: 0106                                  Mean 10 0.47
# Warning: Skipping malformed line: 0106 Q 28  29  12  23  22  16   5  25  27K  3
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0107.tab
# Warning: Skipping malformed line: 0107                                  Mean  9 0.47
# Warning: Skipping malformed line: 0107 Q 28  21   2  20   7  29  13   3   4  27
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0108.tab
# Warning: Skipping malformed line: 0108                                  Mean 11 0.55
# Warning: Skipping malformed line: 0108 Q 16  24  15  11  29   2   8  20K  4  10
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0109.tab
# Warning: Skipping malformed line: 0109                                  Mean 13 0.59
# Warning: Skipping malformed line: 0109 Q 10   7   9  21   1  20   6   2  17   8K
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0110.tab
# Warning: Skipping malformed line: 0110                                  Mean 20 0.76
# Warning: Skipping malformed line: 0110 Q 24  18   7  17  26  27  25A 30A 10A  5A
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0111.tab
# Warning: Skipping malformed line: 0111                                  Mean 16 0.49
# Warning: Skipping malformed line: 0111 Q  3  27  30  28  14  12  29  13  21   9
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0112.tab
# Warning: Skipping malformed line: 0112                                  Mean  9 0.46
# Warning: Skipping malformed line: 0112 Q  9  10  11  13  20   2  28  14  26   7
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0201.tab
# Warning: Skipping malformed line: 0201                                  Mean  8 0.40
# Warning: Skipping malformed line: 0201 Q  3   5  30   4   6   9  16  29  24K 22
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0202.tab
# Warning: Skipping malformed line: 0202                                  Mean 10 0.52
# Warning: Skipping malformed line: 0202 Q 14  15  23   3  16  24  27   4  19K 25
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0203.tab
# Warning: Skipping malformed line: 0203                                  Mean 10 0.50
# Warning: Skipping malformed line: 0203 Q 17  28  14  16  27   8  29K  9  15  13
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0204.tab
# Warning: Skipping malformed line: 0204                                  Mean 17 0.65
# Warning: Skipping malformed line: 0204 Q  8   9  26   5  25   6   4  21  10  15
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0205.tab
# Warning: Skipping malformed line: 0205                                  Mean 12 0.51
# Warning: Skipping malformed line: 0205 Q 24   5  31   1  25   4   3  17   2  30
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0206.tab
# Warning: Skipping malformed line: 0206                                  Mean  7 0.38
# Warning: Skipping malformed line: 0206 Q 28  27  14   1  15   6  17   7  24  29
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0207.tab
# Warning: Skipping malformed line: 0207                                  Mean 11 0.56
# Warning: Skipping malformed line: 0207 Q 14   3  15   2   4K 18  13  11  30K 24A
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0208.tab
# Warning: Skipping malformed line: 0208                                  Mean 14 0.67
# Warning: Skipping malformed line: 0208 Q  6  24   7   5  25   8K 23A 28A 22A 31A
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0209.tab
# Warning: Skipping malformed line: 0209                                  Mean 13 0.56
# Warning: Skipping malformed line: 0209 Q 23  25  24  29  20  28  26  16K 27K 15
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0210.tab
# Warning: Skipping malformed line: 0210                                  Mean 25 1.00
# Warning: Skipping malformed line: 0210 Q 13  12  11  21A 22A 20A 23A 17A 19A 18A
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0211.tab
# Warning: Skipping malformed line: 0211                                  Mean 17 0.83
# Warning: Skipping malformed line: 0211 Q  8   9K 16A  1A 17A 14A 18A 15A 11A 26A
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0212.tab
# Warning: Skipping malformed line: 0212                                  Mean 13 0.65
# Warning: Skipping malformed line: 0212 Q 18  17  11  12  13  10  16   9K 31A 15A
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0301.tab
# Warning: Skipping malformed line: 0301                                  Mean 13 0.65
# Warning: Skipping malformed line: 0301 Q  9   8   6  16   7   2  15A 17A 13A  5A
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0302.tab
# Warning: Skipping malformed line: 0302                                  Mean 17 0.84
# Warning: Skipping malformed line: 0302 Q 25  24  13A 11A 23A 22A 17A 12A  7A 19A
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0303.tab
# Warning: Skipping malformed line: 0303                                  Mean 21 0.96
# Warning: Skipping malformed line: 0303 Q 25  24  26A 12A  8A  9A  2A 11A 19A 13A
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0304.tab
# Warning: Skipping malformed line: 0304                                  Mean 20 0.96
# Warning: Skipping malformed line: 0304 Q  7  12A  6A 13A 19A 27A 20A 28A 11A 26A
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0305.tab
# Warning: Skipping malformed line: 0305                                  Mean 26 1.05
# Warning: Skipping malformed line: 0305 Q  4  17A 18A 16A  3A 20A 19A  5A 23A  2A
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0306.tab
# Warning: Skipping malformed line: 0306                                  Mean 24 1.06
# Warning: Skipping malformed line: 0306 Q 12A 13A  5A 20A 22A 11A  6A 19A 25A 26A
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0307.tab
# Warning: Skipping malformed line: 0307                                  Mean 19 0.87
# Warning: Skipping malformed line: 0307 Q  8   9  22  21A 10A 24A  1A 25A 23A  6A
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0308.tab
# Warning: Skipping malformed line: 0308                                  Mean 23 0.95
# Warning: Skipping malformed line: 0308 Q 31   5A 16A 27A  4A 10A 11A 26A 15A  3A
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0309.tab
# Warning: Skipping malformed line: 0309                                  Mean 18 0.78
# Warning: Skipping malformed line: 0309 Q 28  14  29   7  30  15K  8K 27K  6A 13A
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0310.tab
# Warning: Skipping malformed line: 0310                                  Mean 35 0.94
# Warning: Skipping malformed line: 0310 Q 11  10  12  23   4K  5K  8   2A  9A  6A
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0311.tab
# Warning: Skipping malformed line: 0311                                  Mean 28 1.02
# Warning: Skipping malformed line: 0311 Q 28  27  29   5K  8A 26A  7A 19A 30A  3A
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0312.tab
# Warning: Skipping malformed line: 0312                                  Mean 16 0.75
# Warning: Skipping malformed line: 0312 Q 19   3  18  25  29K 30K  4K 24   2A 17A
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0401.tab
# Warning: Skipping malformed line: 0401                                  Mean 22 1.02
# Warning: Skipping malformed line: 0401 Q  8A 29A 12A 31A 14A 21A  2A 15A 27A 11A
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0402.tab
# Warning: Skipping malformed line: 0402                                  Mean 13 0.65
# Warning: Skipping malformed line: 0402 Q 26  17   8  20  10  25  16A 21A  9A  7A
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0403.tab
# Warning: Skipping malformed line: 0403                                  Mean 14 0.67
# Warning: Skipping malformed line: 0403 Q 24   7   6   8  25   5   4  17K 19A 23A
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0404.tab
# Warning: Skipping malformed line: 0404                                  Mean 11 0.55
# Warning: Skipping malformed line: 0404 Q  2   1  22  20  29  27  14  26  19  13
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0405.tab
# Warning: Skipping malformed line: 0405                                  Mean  8 0.44
# Warning: Skipping malformed line: 0405 Q 26  18  17  27  16  25   9  14  10   2K
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0406.tab
# Warning: Skipping malformed line: 0406                                  Mean  8 0.41
# Warning: Skipping malformed line: 0406 Q 22  23  27  20  25  12  21  13  24  19
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0407.tab
# Warning: Skipping malformed line: 0407                                  Mean 23 0.65
# Warning: Skipping malformed line: 0407 Q  8   7   9  21   6   4  10  29  18   3
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0408.tab
# Warning: Skipping malformed line: 0408                                  Mean  9 0.44
# Warning: Skipping malformed line: 0408 Q  4   8  24   3  25  19  15  23  26  16
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0409.tab
# Warning: Skipping malformed line: 0409                                  Mean  9 0.41
# Warning: Skipping malformed line: 0409 Q 11  10   4  12   3  30  26  25   9  27
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0410.tab
# Warning: Skipping malformed line: 0410                                  Mean  8 0.38
# Warning: Skipping malformed line: 0410 Q 17  26   7  28  23   1   6  27  19  18
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0411.tab
# Warning: Skipping malformed line: 0411                                  Mean 25 0.69
# Warning: Skipping malformed line: 0411 Q  6  15  18   2   5K 19   1K 17K 23  13A
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0412.tab
# Warning: Skipping malformed line: 0412                                  Mean 11 0.56
# Warning: Skipping malformed line: 0412 Q  4   3  19   2  24  20  15  23  14A 31A
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0501.tab
# Warning: Skipping malformed line: 0501                                  Mean 24 0.92
# Warning: Skipping malformed line: 0501 Q 26  27  25   9K  6  10  28K 24A 11A 13A
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0502.tab
# Warning: Skipping malformed line: 0502                                  Mean 11 0.54
# Warning: Skipping malformed line: 0502 Q  5  23   4  15  13  22  12  24K  1K 14
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0503.tab
# Warning: Skipping malformed line: 0503                                  Mean 12 0.54
# Warning: Skipping malformed line: 0503 Q  4  22  12  20  23  15  28   3  29  24
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0504.tab
# Warning: Skipping malformed line: 0504                                  Mean 11 0.47
# Warning: Skipping malformed line: 0504 Q 10  27  26  28  21   2   9   8  17   1
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0505.tab
# Warning: Skipping malformed line: 0505                                  Mean 19 0.68
# Warning: Skipping malformed line: 0505 Q 26  27  25  24   5   6  23   4  14   2A
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0506.tab
# Warning: Skipping malformed line: 0506                                  Mean 12 0.52
# Warning: Skipping malformed line: 0506 Q 21  10  20  28  27   8  19   9  11  29
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0507.tab
# Warning: Skipping malformed line: 0507                                  Mean 14 0.64
# Warning: Skipping malformed line: 0507 Q  6  24   5  25   8  26   4  23  15   7
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0508.tab
# Warning: Skipping malformed line: 0508                                  Mean 14 0.58
# Warning: Skipping malformed line: 0508 Q 11  20  30  12K 28  27  19  15K 26K  8
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0509.tab
# Warning: Skipping malformed line: 0509                                  Mean 20 0.76
# Warning: Skipping malformed line: 0509 Q 24  21  20  25K  8  23K 22  19  29A  6A
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0510.tab
# Warning: Skipping malformed line: 0510                                  Mean  8 0.36
# Warning: Skipping malformed line: 0510 Q 15  12  23  20  14  21   5   4  29   6
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0511.tab
# Warning: Skipping malformed line: 0511                                  Mean  8 0.43
# Warning: Skipping malformed line: 0511 Q 16  27  10   8  17   9  15  18  21  26
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0512.tab
# Warning: Skipping malformed line: 0512                                  Mean  9 0.43
# Warning: Skipping malformed line: 0512 Q 23   7   8   6  15   5  14  18  17  24
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0601.tab
# Warning: Skipping malformed line: 0601                                  Mean  6 0.29
# Warning: Skipping malformed line: 0601 Q  9  10  30   4  31  29  11  13  14  12
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0602.tab
# Warning: Skipping malformed line: 0602                                  Mean  6 0.29
# Warning: Skipping malformed line: 0602 Q 14  25   9  18  13   5  27   1   8   2
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0603.tab
# Warning: Skipping malformed line: 0603                                  Mean  8 0.36
# Warning: Skipping malformed line: 0603 Q  5  13   2   3   4  17  14  23  30   9
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0604.tab
# Warning: Skipping malformed line: 0604                                  Mean 11 0.43
# Warning: Skipping malformed line: 0604 Q 30  12   1   3   2  29   7  19  26  27
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0605.tab
# Warning: Skipping malformed line: 0605                                  Mean  7 0.33
# Warning: Skipping malformed line: 0605 Q 16   1  27  29   9  15  26   3   2  25
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0606.tab
# Warning: Skipping malformed line: 0606                                  Mean  8 0.34
# Warning: Skipping malformed line: 0606 Q 26   4  23  21  13   5  24  19  20  12
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0607.tab
# Warning: Skipping malformed line: 0607                                  Mean  6 0.28
# Warning: Skipping malformed line: 0607 Q 21   2  18  19   8  20   3  16  17  23
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0608.tab
# Warning: Skipping malformed line: 0608                                  Mean  9 0.41
# Warning: Skipping malformed line: 0608 Q 13  25   4  16  14  26   6  15   5  24
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0609.tab
# Warning: Skipping malformed line: 0609                                  Mean  8 0.36
# Warning: Skipping malformed line: 0609 Q 15  22   9  21  16  28  27   8  20  29
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0610.tab
# Warning: Skipping malformed line: 0610                                  Mean  9 0.40
# Warning: Skipping malformed line: 0610 Q 10  19  26   6  11  17  23   5  18   4
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0611.tab
# Warning: Skipping malformed line: 0611                                  Mean  9 0.42
# Warning: Skipping malformed line: 0611 Q  7   8  20  21  18  13   6  19   5  14K
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0612.tab
# Warning: Skipping malformed line: 0612                                  Mean 15 0.61
# Warning: Skipping malformed line: 0612 Q  4  31  27   2  29  30  28   3   5  26
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0701.tab
# Warning: Skipping malformed line: 0701                                  Mean 10 0.47
# Warning: Skipping malformed line: 0701 Q 13   7  24  25  26  22   8  23   9  14
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0702.tab
# Warning: Skipping malformed line: 0702                                  Mean  7 0.32
# Warning: Skipping malformed line: 0702 Q 21  20   4  24  22  23  11  19   3  25
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0703.tab
# Warning: Skipping malformed line: 0703                                  Mean  8 0.40
# Warning: Skipping malformed line: 0703 Q 20  21   3  19   9  29  22  18  31   4
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0704.tab
# Warning: Skipping malformed line: 0704                                  Mean  9 0.43
# Warning: Skipping malformed line: 0704 Q 16  13  21  20   8   5   6   7  24  11
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0705.tab
# Warning: Skipping malformed line: 0705                                  Mean  8 0.35
# Warning: Skipping malformed line: 0705 Q  6   5   2  12  13  11   4  14  16  30
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0706.tab
# Warning: Skipping malformed line: 0706                                  Mean  6 0.28
# Warning: Skipping malformed line: 0706 Q  5  12   6   7  11  26  25  20  30  28
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0707.tab
# Warning: Skipping malformed line: 0707                                  Mean  7 0.31
# Warning: Skipping malformed line: 0707 Q  9  25  19  18  24   2  22  23  17  16
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0708.tab
# Warning: Skipping malformed line: 0708                                  Mean  6 0.29
# Warning: Skipping malformed line: 0708 Q 24   4  23   5  13  20  18   9  22   3
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0709.tab
# Warning: Skipping malformed line: 0709                                  Mean  9 0.44
# Warning: Skipping malformed line: 0709 Q 13   9  10  11  12  16  17  19  26  15
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0710.tab
# Warning: Skipping malformed line: 0710                                  Mean  7 0.33
# Warning: Skipping malformed line: 0710 Q  9   8  11  17  10   7  15  13  16  24
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0711.tab
# Warning: Skipping malformed line: 0711                                  Mean  7 0.31
# Warning: Skipping malformed line: 0711 Q  7   6   3  11   2  30   5  18  12  29
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0712.tab
# Warning: Skipping malformed line: 0712                                  Mean  6 0.28
# Warning: Skipping malformed line: 0712 Q  3   8   4  25   7  26   2  29  15   6
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0801.tab
# Warning: Skipping malformed line: 0801                                  Mean  8 0.39
# Warning: Skipping malformed line: 0801 Q  3   2  22  30   4  11   1  27  10  28
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0802.tab
# Warning: Skipping malformed line: 0802                                  Mean 11 0.53
# Warning: Skipping malformed line: 0802 Q 24  25  22  26   9   5   6  23  17  21
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0803.tab
# Warning: Skipping malformed line: 0803                                  Mean 11 0.55
# Warning: Skipping malformed line: 0803 Q  7   6  24  25   4  31  22  17   3  21
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0804.tab
# Warning: Skipping malformed line: 0804                                  Mean  9 0.46
# Warning: Skipping malformed line: 0804 Q  2  14   3  20   1  11  21  15K 19  29K
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0805.tab
# Warning: Skipping malformed line: 0805                                  Mean  6 0.31
# Warning: Skipping malformed line: 0805 Q 17  14  15  18   9  12  26  27  11  13
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0806.tab
# Warning: Skipping malformed line: 0806                                  Mean  7 0.33
# Warning: Skipping malformed line: 0806 Q 13  10   5  22  11  12   4   9  21  23
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0807.tab
# Warning: Skipping malformed line: 0807                                  Mean  5 0.22
# Warning: Skipping malformed line: 0807 Q 19   8   7   9   2  25   3  31  20  29
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0808.tab
# Warning: Skipping malformed line: 0808                                  Mean  5 0.18
# Warning: Skipping malformed line: 0808 Q 25   2  26  24  30   5  29  28   4  22
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0809.tab
# Warning: Skipping malformed line: 0809                                  Mean  6 0.22
# Warning: Skipping malformed line: 0809 Q 13  12  29  21  24  11  23   2  28  26
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0810.tab
# Warning: Skipping malformed line: 0810                                  Mean  7 0.29
# Warning: Skipping malformed line: 0810 Q  9  18  25  24  27  17   7   8  10  14
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0811.tab
# Warning: Skipping malformed line: 0811                                  Mean  4 0.18
# Warning: Skipping malformed line: 0811 Q 22  21   3  14  18  13   5  19   6   4
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0812.tab
# Warning: Skipping malformed line: 0812                                  Mean  4 0.18
# Warning: Skipping malformed line: 0812 Q  1   2   9  29  14  30  18  21  20  28
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0901.tab
# Warning: Skipping malformed line: 0901                                  Mean  4 0.16
# Warning: Skipping malformed line: 0901 Q 12  22  23  11  24  28   7  18  25  17
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0902.tab
# Warning: Skipping malformed line: 0902                                  Mean  5 0.18
# Warning: Skipping malformed line: 0902 Q  8   2  17  10  19  13  26   9   6   7
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0903.tab
# Warning: Skipping malformed line: 0903                                  Mean  5 0.22
# Warning: Skipping malformed line: 0903 Q  2   7   9  18   6  23   1  31  29  28
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0904.tab
# Warning: Skipping malformed line: 0904                                  Mean  4 0.16
# Warning: Skipping malformed line: 0904 Q  4  23   2  30   7   3  28  14  26  29
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0905.tab
# Warning: Skipping malformed line: 0905                                  Mean  4 0.13
# Warning: Skipping malformed line: 0905 Q 12  27  25  17   5  15  26  13  19   1
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0906.tab
# Warning: Skipping malformed line: 0906                                  Mean  4 0.16
# Warning: Skipping malformed line: 0906 Q 12   1  17   9  22  19   2  11   8  26
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0907.tab
# Warning: Skipping malformed line: 0907                                  Mean  4 0.16
# Warning: Skipping malformed line: 0907 Q 17  19  18   2  26  16  29  27   1   4
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0908.tab
# Warning: Skipping malformed line: 0908                                  Mean  5 0.18
# Warning: Skipping malformed line: 0908 Q 16  24  15  29  17  25  28  14  18  11
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0909.tab
# Warning: Skipping malformed line: 0909                                  Mean  4 0.12
# Warning: Skipping malformed line: 0909 Q 23  29  24  19  25  12   9   8   7   5
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0910.tab
# Warning: Skipping malformed line: 0910                                  Mean  3 0.13
# Warning: Skipping malformed line: 0910 Q 14  20  10  17   3  18   2  12  21   6
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0911.tab
# Warning: Skipping malformed line: 0911                                  Mean  3 0.08
# Warning: Skipping malformed line: 0911 Q  6  23  29   3   5  30   4  11  16  10
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp0912.tab
# Warning: Skipping malformed line: 0912                                  Mean  2 0.03
# Warning: Skipping malformed line: 0912 Q  1   3   4  11  30   9  29  31   8   2
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1001.tab
# Warning: Skipping malformed line: 1001                                  Mean  3 0.10
# Warning: Skipping malformed line: 1001 Q 17   7   9   2   8  27   6  16  19   1
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1002.tab
# Warning: Skipping malformed line: 1002                                  Mean  5 0.18
# Warning: Skipping malformed line: 1002 Q 20  21  27   5  28   9  26  10  23   7
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1003.tab
# Warning: Skipping malformed line: 1003                                  Mean  5 0.19
# Warning: Skipping malformed line: 1003 Q 22  23  21   9   8  13  15   5  19  16
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1004.tab
# Warning: Skipping malformed line: 1004                                  Mean 10 0.44
# Warning: Skipping malformed line: 1004 Q 26  10  18  25  30  16  28  13  17  20
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1005.tab
# Warning: Skipping malformed line: 1005                                  Mean  8 0.36
# Warning: Skipping malformed line: 1005 Q 23  24  27   9  13  15   1  14  22  16
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1006.tab
# Warning: Skipping malformed line: 1006                                  Mean  7 0.32
# Warning: Skipping malformed line: 1006 Q 12  20   8  19   9  23  14  11  22   7
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1007.tab
# Warning: Skipping malformed line: 1007                                  Mean  5 0.22
# Warning: Skipping malformed line: 1007 Q 10  17  18   7  13   6  19   8   5  16
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1008.tab
# Warning: Skipping malformed line: 1008                                  Mean  8 0.33
# Warning: Skipping malformed line: 1008 Q 30  22  21  29  14  20  31  13  19   7
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1009.tab
# Warning: Skipping malformed line: 1009                                  Mean  5 0.23
# Warning: Skipping malformed line: 1009 Q 11  12  30   4  22  10   3  13  19  20
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1010.tab
# Warning: Skipping malformed line: 1010                                  Mean  6 0.26
# Warning: Skipping malformed line: 1010 Q  2  14   1   3   4  30  21   7  28  10
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1011.tab
# Warning: Skipping malformed line: 1011                                  Mean  5 0.24
# Warning: Skipping malformed line: 1011 Q  6  26  19   2   7   5  20   9  30   1
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1012.tab
# Warning: Skipping malformed line: 1012                                  Mean  4 0.17
# Warning: Skipping malformed line: 1012 Q 10  22  11   3  23   9   4   5  21   1
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1101.tab
# Warning: Skipping malformed line: 1101                                  Mean  6 0.25
# Warning: Skipping malformed line: 1101 Q 30  23   5  27  21  22  26   1   2  29
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1102.tab
# Warning: Skipping malformed line: 1102                                  Mean  6 0.28
# Warning: Skipping malformed line: 1102 Q  3   9  27  13  28  24  23  25  17  22
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1103.tab
# Warning: Skipping malformed line: 1103                                  Mean  8 0.37
# Warning: Skipping malformed line: 1103 Q 15  26  16  27  18  28  31  14  29  25
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1104.tab
# Warning: Skipping malformed line: 1104                                  Mean  9 0.41
# Warning: Skipping malformed line: 1104 Q 27  26  10  28  16  17  23  21  15  14
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1105.tab
# Warning: Skipping malformed line: 1105                                  Mean  9 0.39
# Warning: Skipping malformed line: 1105 Q 20   8  12  25   9  13   6  19  14  23
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1106.tab
# Warning: Skipping malformed line: 1106                                  Mean  8 0.41
# Warning: Skipping malformed line: 1106 Q 29   3  28  19  27  18  30  16   6  25
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1107.tab
# Warning: Skipping malformed line: 1107                                  Mean  8 0.42
# Warning: Skipping malformed line: 1107 Q 27  28  16  24  17  29  15   2  26  18
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1108.tab
# Warning: Skipping malformed line: 1108                                  Mean  7 0.31
# Warning: Skipping malformed line: 1108 Q 31  18  19   3  21   2  30  13  12  11
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1109.tab
# Warning: Skipping malformed line: 1109                                  Mean 12 0.52
# Warning: Skipping malformed line: 1109 Q 23  19   1  16   8   2  24  22  14  25
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1110.tab
# Warning: Skipping malformed line: 1110                                  Mean  7 0.32
# Warning: Skipping malformed line: 1110 Q 28  29  22  14  23  10  13  26  11  18
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1111.tab
# Warning: Skipping malformed line: 1111                                  Mean  5 0.21
# Warning: Skipping malformed line: 1111 Q 19  14   9  20  13  18  10   5   3  16
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1112.tab
# Warning: Skipping malformed line: 1112                                  Mean  4 0.15
# Warning: Skipping malformed line: 1112 Q 27  16  26  17   6  15   7  23  24  18
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1201.tab
# Warning: Skipping malformed line: 1201                                  Mean  7 0.33
# Warning: Skipping malformed line: 1201 Q 14  19   4  31  18  20   8   1   2  15
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1202.tab
# Warning: Skipping malformed line: 1202                                  Mean  9 0.44
# Warning: Skipping malformed line: 1202 Q 17  23  12   2  16  11  10  18K 24K  9
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1203.tab
# Warning: Skipping malformed line: 1203                                  Mean 16 0.67
# Warning: Skipping malformed line: 1203 Q 26  29  25  31  20  30  21  23K  3A 22A
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1204.tab
# Warning: Skipping malformed line: 1204                                  Mean 10 0.47
# Warning: Skipping malformed line: 1204 Q 30   6   9   8  16  29  15  11   3  19K
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1205.tab
# Warning: Skipping malformed line: 1205                                  Mean  7 0.34
# Warning: Skipping malformed line: 1205 Q 27   7   5   1  26  17   4  14   2   6
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1206.tab
# Warning: Skipping malformed line: 1206                                  Mean 10 0.46
# Warning: Skipping malformed line: 1206 Q 19  15  21  14  20  24  23  22  13  29
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1207.tab
# Warning: Skipping malformed line: 1207                                  Mean 14 0.61
# Warning: Skipping malformed line: 1207 Q 13  26  27  18  31  19  29  25K 22   7A
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1208.tab
# Warning: Skipping malformed line: 1208                                  Mean  7 0.35
# Warning: Skipping malformed line: 1208 Q 31  10  30  28  29  11   5   1   9  15
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1209.tab
# Warning: Skipping malformed line: 1209                                  Mean  8 0.38
# Warning: Skipping malformed line: 1209 Q 23  28  11  25  24  29  10   9  22  17
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1210.tab
# Warning: Skipping malformed line: 1210                                  Mean 10 0.38
# Warning: Skipping malformed line: 1210 Q 20   4  29  30  22  21  28  25  19  27
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1211.tab
# Warning: Skipping malformed line: 1211                                  Mean  7 0.30
# Warning: Skipping malformed line: 1211 Q  9  30  28   4  11  22   3  29  10   8
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1212.tab
# Warning: Skipping malformed line: 1212                                  Mean  3 0.12
# Warning: Skipping malformed line: 1212 Q  6   8  22   7  27  31  12  23  28   5
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1301.tab
# Warning: Skipping malformed line: 1301                                  Mean  5 0.22
# Warning: Skipping malformed line: 1301 Q  1  22   5  30  10  31   3  23  24   4
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1302.tab
# Warning: Skipping malformed line: 1302                                  Mean  6 0.29
# Warning: Skipping malformed line: 1302 Q  6   5  24  25   9  27  15   3  18K 10
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1303.tab
# Warning: Skipping malformed line: 1303                                  Mean 11 0.44
# Warning: Skipping malformed line: 1303 Q  8   7  26  25  13  10   6   5  31   4
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1304.tab
# Warning: Skipping malformed line: 1304                                  Mean  5 0.22
# Warning: Skipping malformed line: 1304 Q 19   8  18  17  21   3   5   9  20   2
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1305.tab
# Warning: Skipping malformed line: 1305                                  Mean 10 0.47
# Warning: Skipping malformed line: 1305 Q 29  30  11  12   9  10  13   4  21   3
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1306.tab
# Warning: Skipping malformed line: 1306                                  Mean 13 0.55
# Warning: Skipping malformed line: 1306 Q 16  26  17  13  14  18  12  15  19   5
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1307.tab
# Warning: Skipping malformed line: 1307                                  Mean  9 0.45
# Warning: Skipping malformed line: 1307 Q  2   3  17   8  21   4  24  31  23  16
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1308.tab
# Warning: Skipping malformed line: 1308                                  Mean  8 0.40
# Warning: Skipping malformed line: 1308 Q 29   2   7   8  20  11   3  19   1  26
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1309.tab
# Warning: Skipping malformed line: 1309                                  Mean  5 0.23
# Warning: Skipping malformed line: 1309 Q 28  26  27  15  29   7  30   9   5  16
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1310.tab
# Warning: Skipping malformed line: 1310                                  Mean  8 0.31
# Warning: Skipping malformed line: 1310 Q  5  28   4  19  21  20  26  24  25  13
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1311.tab
# Warning: Skipping malformed line: 1311                                  Mean  6 0.26
# Warning: Skipping malformed line: 1311 Q 25  24  21  27  28  26  12  18  14  22
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1312.tab
# Warning: Skipping malformed line: 1312                                  Mean  5 0.18
# Warning: Skipping malformed line: 1312 Q  2  12  22  26  27  23  30  28  24  11
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1401.tab
# Warning: Skipping malformed line: 1401                                  Mean  5 0.25
# Warning: Skipping malformed line: 1401 Q 19  31  18  20  16  17   5   6  27  15
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1402.tab
# Warning: Skipping malformed line: 1402                                  Mean 11 0.49
# Warning: Skipping malformed line: 1402 Q 13  26  14  25   2   4   5   1  17  24
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1403.tab
# Warning: Skipping malformed line: 1403                                  Mean  5 0.19
# Warning: Skipping malformed line: 1403 Q 16   9  17   7   8  11  24  10  15  19
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1404.tab
# Warning: Skipping malformed line: 1404                                  Mean  8 0.38
# Warning: Skipping malformed line: 1404 Q 10   6  27   2  22  16   9   8  29K 15
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1405.tab
# Warning: Skipping malformed line: 1405                                  Mean  6 0.25
# Warning: Skipping malformed line: 1405 Q 21   6  31  17  26   2  13   7  25  27
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1406.tab
# Warning: Skipping malformed line: 1406                                  Mean  7 0.28
# Warning: Skipping malformed line: 1406 Q  1  12  27  15  22   2  26  23K 13  16
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1407.tab
# Warning: Skipping malformed line: 1407                                  Mean  5 0.17
# Warning: Skipping malformed line: 1407 Q 19  18  20   1  29   6   5  17  30  16
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1408.tab
# Warning: Skipping malformed line: 1408                                  Mean  8 0.38
# Warning: Skipping malformed line: 1408 Q 16  25  24   9  26  22  15  14  23  18
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1409.tab
# Warning: Skipping malformed line: 1409                                  Mean 10 0.49
# Warning: Skipping malformed line: 1409 Q 14  15   8  17  20  21K  4  18K  7A 10K
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1410.tab
# Warning: Skipping malformed line: 1410                                  Mean  9 0.46
# Warning: Skipping malformed line: 1410 Q 12   3  30   4   5   7K 31   6K 13K 16K
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1411.tab
# Warning: Skipping malformed line: 1411                                  Mean  9 0.48
# Warning: Skipping malformed line: 1411 Q 29  26  13  28   3  25  24   1A 27A  6A
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1412.tab
# Warning: Skipping malformed line: 1412                                  Mean 11 0.60
# Warning: Skipping malformed line: 1412 Q 11  18  17  16  27K  3A 20A 19A 31A 10A
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1501.tab
# Warning: Skipping malformed line: 1501                                  Mean  9 0.48
# Warning: Skipping malformed line: 1501 Q 20  18  19  25  15K 24   1  14  17K  9
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1502.tab
# Warning: Skipping malformed line: 1502                                  Mean 10 0.49
# Warning: Skipping malformed line: 1502 Q 13  27  14  26  12  20  16   6  11K 15K
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1503.tab
# Warning: Skipping malformed line: 1503                                  Mean 16 0.67
# Warning: Skipping malformed line: 1503 Q 10  30   5  14   9K 15  13K 27A 26A 12A
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1504.tab
# Warning: Skipping malformed line: 1504                                  Mean 11 0.49
# Warning: Skipping malformed line: 1504 Q 25  26  12   8  29  24  30   7  27  28
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1505.tab
# Warning: Skipping malformed line: 1505                                  Mean  8 0.37
# Warning: Skipping malformed line: 1505 Q 25  21  22  23  24  30  31  16  17  27
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1506.tab
# Warning: Skipping malformed line: 1506                                  Mean 13 0.55
# Warning: Skipping malformed line: 1506 Q 20   5   2   4   3  19   6  29  30  12
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1507.tab
# Warning: Skipping malformed line: 1507                                  Mean  9 0.42
# Warning: Skipping malformed line: 1507 Q 19   2   3  18  20   8  17   9  29   7
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1508.tab
# Warning: Skipping malformed line: 1508                                  Mean 14 0.65
# Warning: Skipping malformed line: 1508 Q 14  30  31   5  21   4   3  24K 11A 25A
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1509.tab
# Warning: Skipping malformed line: 1509                                  Mean 16 0.68
# Warning: Skipping malformed line: 1509 Q 30  27  28  26   1  29  25K 24A  2A  3A
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1510.tab
# Warning: Skipping malformed line: 1510                                  Mean 14 0.62
# Warning: Skipping malformed line: 1510 Q 26  28  27  19  29  22  23  31  16K 25
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1511.tab
# Warning: Skipping malformed line: 1511                                  Mean 12 0.56
# Warning: Skipping malformed line: 1511 Q 24  25  23  22  26  21  12  20   2  28
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1512.tab
# Warning: Skipping malformed line: 1512                                  Mean 14 0.65
# Warning: Skipping malformed line: 1512 Q 30   3   4  28  18  29  16K 13A 17K 25A
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1601.tab
# Warning: Skipping malformed line: 1601                                  Mean  9 0.45
# Warning: Skipping malformed line: 1601 Q 25  30  29  16  17  26  27  15  18K  4
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1602.tab
# Warning: Skipping malformed line: 1602                                  Mean 10 0.46
# Warning: Skipping malformed line: 1602 Q 22  28  27  21  29  10   4  25  20   2
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1603.tab
# Warning: Skipping malformed line: 1603                                  Mean 11 0.53
# Warning: Skipping malformed line: 1603 Q 26  13   5   4  25K 22  24  31K  9   3
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1604.tab
# Warning: Skipping malformed line: 1604                                  Mean  9 0.44
# Warning: Skipping malformed line: 1604 Q 19   9  29   1  20  28  21  25  18  11K
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp1605.tab
# ...
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp2006.tab
# Warning: Skipping malformed line: 2006                                  Mean  4 0.11
# Warning: Skipping malformed line: 2006 Q 29  22  14   6  25  12  13   3  28  15
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp2007.tab
# Warning: Skipping malformed line: 2007                                  Mean  4 0.15
# Warning: Skipping malformed line: 2007 Q  8  12  11  10  23  26  22   9  20  27
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp2008.tab
# Warning: Skipping malformed line: 2008                                  Mean  6 0.25
# Warning: Skipping malformed line: 2008 Q  9  10  15  11  24  20  17   1  25  16
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp2009.tab
# Warning: Skipping malformed line: 2009                                  Mean  9 0.40
# Warning: Skipping malformed line: 2009 Q  9  10  21  11  19  16  17   8   3   7
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp2010.tab
# Warning: Skipping malformed line: 2010                                  Mean  6 0.29
# Warning: Skipping malformed line: 2010 Q 14   9  10  15   8  18  13  11  12  16
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp2011.tab
# Warning: Skipping malformed line: 2011                                  Mean  5 0.19
# Warning: Skipping malformed line: 2011 Q  9  10  16   4   2  17  19   3  18  13
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp2012.tab
# Warning: Skipping malformed line: 2012                                  Mean  5 0.19
# Warning: Skipping malformed line: 2012 Q  4  17  18   7   1  16  15   3  31   2
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp2101.tab
# Warning: Skipping malformed line: 2101                                  Mean  4 0.18
# Warning: Skipping malformed line: 2101 Q  2   3  14   8  31  30   4  21  17   9
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp2102.tab
# Warning: Skipping malformed line: 2102                                  Mean 10 0.48
# Warning: Skipping malformed line: 2102 Q 11  10  27   9  14  18  15   1   5  28
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp2103.tab
# Warning: Skipping malformed line: 2103                                  Mean 10 0.50
# Warning: Skipping malformed line: 2103 Q 10  16   9  29  30  11  18  17   5   8K
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp2104.tab
# Warning: Skipping malformed line: 2104                                  Mean  8 0.40
# Warning: Skipping malformed line: 2104 Q  6  28   4   3   9   8  29  10   5  12
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp2105.tab
# Warning: Skipping malformed line: 2105                                  Mean  7 0.26
# Warning: Skipping malformed line: 2105 Q  5  28  31  24   7  25  11   9   8   6
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp2106.tab
# Warning: Skipping malformed line: 2106                                  Mean  6 0.25
# Warning: Skipping malformed line: 2106 Q  1  28  27   9  19  26  21  14  23   4
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp2107.tab
# Warning: Skipping malformed line: 2107                                  Mean  6 0.24
# Warning: Skipping malformed line: 2107 Q 25   4  23  24  26  11  17   8  16   3
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp2108.tab
# Warning: Skipping malformed line: 2108                                  Mean  6 0.29
# Warning: Skipping malformed line: 2108 Q  5  23  22  14   1  21   9  12  19   8
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp2109.tab
# Warning: Skipping malformed line: 2109                                  Mean  7 0.31
# Warning: Skipping malformed line: 2109 Q 26  19  20  16   2   9   1  29   4  15
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp2110.tab
# Warning: Skipping malformed line: 2110                                  Mean  7 0.32
# Warning: Skipping malformed line: 2110 Q 28  27  29   7  23  22  24   8   9  25
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp2111.tab
# Warning: Skipping malformed line: 2111                                  Mean 10 0.43
# Warning: Skipping malformed line: 2111 Q 13  26  14  12  11  24  27K 19  25  18
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp2112.tab
# Warning: Skipping malformed line: 2112                                  Mean  6 0.30
# Warning: Skipping malformed line: 2112 Q  9  10  17  26  12  18   8  31  23   7
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp2201.tab
# Warning: Skipping malformed line: 2201                                  Mean  9 0.45
# Warning: Skipping malformed line: 2201 Q  7   6  13  12  24   5  11  20K  4K 10
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp2202.tab
# Warning: Skipping malformed line: 2202                                  Mean 10 0.53
# Warning: Skipping malformed line: 2202 Q 26   9  15   8  17  18   1K 24K  7  23
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp2203.tab
# Warning: Skipping malformed line: 2203                                  Mean 10 0.49
# Warning: Skipping malformed line: 2203 Q 18   2  21   3  19   9  17   8  16  23
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp2204.tab
# Warning: Skipping malformed line: 2204                                  Mean 12 0.59
# Warning: Skipping malformed line: 2204 Q 26  25  24   5   6  22  19K 16A  8A  3A
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp2205.tab
# Warning: Skipping malformed line: 2205                                  Mean  7 0.38
# Warning: Skipping malformed line: 2205 Q  7  10   5  24  26   6  23  11   2   8
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp2206.tab
# Warning: Skipping malformed line: 2206                                  Mean  8 0.41
# Warning: Skipping malformed line: 2206 Q  4  30   3   5   2  10   9   8  29   1
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp2207.tab
# Warning: Skipping malformed line: 2207                                  Mean 10 0.46
# Warning: Skipping malformed line: 2207 Q  5  17  29  14   6  13  25   9  20  10
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp2208.tab
# Warning: Skipping malformed line: 2208                                  Mean 11 0.52
# Warning: Skipping malformed line: 2208 Q 24   6  25  23  26  16  15  14   4   5K
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp2209.tab
# Warning: Skipping malformed line: 2209                                  Mean 12 0.55
# Warning: Skipping malformed line: 2209 Q 13  28  16  17  21  26K 25  22K 29  15K
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp2210.tab
# Warning: Skipping malformed line: 2210                                  Mean 11 0.57
# Warning: Skipping malformed line: 2210 Q  1  13  19  25  21  17K 26  12  18  11K
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp2211.tab
# Warning: Skipping malformed line: 2211                                  Mean  9 0.46
# Warning: Skipping malformed line: 2211 Q 10  17  15  22   6  23  16  14  19  12
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp2212.tab
# Warning: Skipping malformed line: 2212                                  Mean 11 0.55
# Warning: Skipping malformed line: 2212 Q 17  13   6  18  14  16  28  20  15  12
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp2301.tab
# Warning: Skipping malformed line: 2301                                  Mean  9 0.44
# Warning: Skipping malformed line: 2301 Q  6  24  30   9  29  20  17K  3   7  19K
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp2302.tab
# Warning: Skipping malformed line: 2302                                  Mean 14 0.63
# Warning: Skipping malformed line: 2302 Q 13   5  24   2K  4K  1  19  17K 18  14
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp2303.tab
# Warning: Skipping malformed line: 2303                                  Mean 14 0.64
# Warning: Skipping malformed line: 2303 Q 27  13  28  29  17  16K 11K 21  26A  8A
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp2304.tab
# Warning: Skipping malformed line: 2304                                  Mean 13 0.58
# Warning: Skipping malformed line: 2304 Q 12  16  17  20  11   8  13   9K 14  22
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp2305.tab
# Warning: Skipping malformed line: 2305                                  Mean 11 0.51
# Warning: Skipping malformed line: 2305 Q 18  17   5  29   3  27  30  26  15   4
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp2306.tab
# Warning: Skipping malformed line: 2306                                  Mean  9 0.45
# Warning: Skipping malformed line: 2306 Q  3   9  10   7   5  14   8   2  13   6
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp2307.tab
# Warning: Skipping malformed line: 2307                                  Mean  8 0.41
# Warning: Skipping malformed line: 2307 Q  4   9   3  19  10   2   1  28  31   5
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp2308.tab
# Warning: Skipping malformed line: 2308                                  Mean  7 0.34
# Warning: Skipping malformed line: 2308 Q  6  15  23  11  14  25  13  29  30   3
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp2309.tab
# Warning: Skipping malformed line: 2309                                  Mean 14 0.67
# Warning: Skipping malformed line: 2309 Q 10   7  11  28K  8  16K  4   6K 15K  9A
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp2310.tab
# Warning: Skipping malformed line: 2310                                  Mean  8 0.40
# Warning: Skipping malformed line: 2310 Q 17  23  12  11  24  15  16  25  10   7
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp2311.tab
# Warning: Skipping malformed line: 2311                                  Mean 12 0.54
# Warning: Skipping malformed line: 2311 Q 18   3  19  17  11  29  20  30   2  14K
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp2312.tab
# Warning: Skipping malformed line: 2312                                  Mean 10 0.43
# Warning: Skipping malformed line: 2312 Q  9  11  22  28  31  25  10  27  30   8
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp2401.tab
# Warning: Skipping malformed line: 2401                                  Mean  5 0.24
# Warning: Skipping malformed line: 2401 Q  7  13   6  17   8  12  27   5  21  26
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp2402.tab
# Warning: Skipping malformed line: 2402                                  Mean  5 0.23
# Warning: Skipping malformed line: 2402 Q 19   3   2  23  15  21   7  29  16  17
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp2403.tab
# Warning: Skipping malformed line: 2403                                  Mean 11 0.46
# Warning: Skipping malformed line: 2403 Q 17  16  30  11  20  18   2  29  12   6K
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp2404.tab
# Warning: Skipping malformed line: 2404                                  Mean 10 0.46
# Warning: Skipping malformed line: 2404 Q 25  24  18  14  12  11  13   3  29  28K
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp2405.tab
# Warning: Skipping malformed line: 2405                                  Mean 24 0.65
# Warning: Skipping malformed line: 2405 Q 22  28   9   4K 25   8  29  20   7  14
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp2406.tab
# Warning: Skipping malformed line: 2406                                  Mean 10 0.47
# Warning: Skipping malformed line: 2406 Q 13  22  21  24  12   2   9   1   6  14
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp2407.tab
# Warning: Skipping malformed line: 2407                                  Mean  7 0.34
# Warning: Skipping malformed line: 2407 Q  6  13  19  18   2   3  21  14  10  23
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp2408.tab
# Warning: Skipping malformed line: 2408                                  Mean 16 0.62
# Warning: Skipping malformed line: 2408 Q 26  15  29   6  25   9   8  23   7  10
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp2409.tab
# Warning: Skipping malformed line: 2409                                  Mean 15 0.65
# Warning: Skipping malformed line: 2409 Q  5  22  21  20K  3  27  10   6K 28K  7
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp2410.tab
# Warning: Skipping malformed line: 2410                                  Mean 19 0.68
# Warning: Skipping malformed line: 2410 Q 25  13  21   1   2   5  20K 14K  3A 17A
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp2411.tab
# Warning: Skipping malformed line: 2411                                  Mean  9 0.49
# Warning: Skipping malformed line: 2411 Q 28  18  12  27  26K 13   1K 17K 16K 29A
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp2412.tab
# Warning: Skipping malformed line: 2412                                  Mean  8 0.43
# Warning: Skipping malformed line: 2412 Q 26  27  28  13  29   6   5   7  12  25
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp2501.tab
# Warning: Skipping malformed line: 2501                                  Mean 13 0.61
# Warning: Skipping malformed line: 2501 Q 26  25  30  29  27  12  24  11K 31   8A
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp2502.tab
# Warning: Skipping malformed line: 2502                                  Mean 14 0.71
# Warning: Skipping malformed line: 2502 Q  7   3   4  21  22   5  23K 20K  6A 25A
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp2503.tab
# Warning: Skipping malformed line: 2503                                  Mean 16 0.76
# Warning: Skipping malformed line: 2503 Q  3   2  31  30  20   6  29A 10A 11A 16A
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp2504.tab
# Warning: Skipping malformed line: 2504                                  Mean 18 0.80
# Warning: Skipping malformed line: 2504 Q 28  25   1  29  26  23  27  17A 30A  7A
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp2505.tab
# Warning: Skipping malformed line: 2505                                  Mean 17 0.80
# Warning: Skipping malformed line: 2505 Q 24  12  25  22   7A 26A 23A 19A 13A 16A
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp2506.tab
# Warning: Skipping malformed line: 2506                                  Mean 21 0.83
# Warning: Skipping malformed line: 2506 Q 23   6A 29A 24A 10A 17A 28A 15A 20A 21A
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp2507.tab
# Warning: Skipping malformed line: 2507                                  Mean 12 0.61
# Warning: Skipping malformed line: 2507 Q 10  21  27  20  28   2   1K 19  29   9A
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp2508.tab
# Warning: Skipping malformed line: 2508                                  Mean 10 0.49
# Warning: Skipping malformed line: 2508 Q  7  17  16  24  23  29   6  28  15  18K
# Fetching historical data: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp2509.tab
# Error fetching http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp2509.tab: 404 Client Error: Not Found for url: http://ftp.gwdg.de/pub/geophys/kp-ap/tab/kp2509.tab
# Fetching previous month's data: https://www-app3.gfz-potsdam.de/kp_index/pqlyymm.tab
# Warning: Skipping malformed line: 2510                                  Mean 16 0.71
# Fetching current month's data: https://www-app3.gfz-potsdam.de/kp_index/qlyymm.tab
# Writing complete dataset to 'data/ap_index2.dat'...
# Update process finished.

# %% [markdown]
# ## North geomagnetic pole
# The following cell updates the ap geomagnetic index in the file `ap_index2.dat`.

# %%
def scrape_geomagnetic_poles(url):
    """
    Scrapes the geomagnetic poles table from a given URL
    using pandas to correctly handle complex headers.

    Args:
        url (str): The URL of the web page to scrape.

    Returns:
        pandas.DataFrame: A pandas DataFrame containing the table data.
                          Returns None if an error occurs.
    """
    try:
        # 1. Send an HTTP request to get the page content
        print(f"Contacting URL: {url}...")
        response = requests.get(url)
        # Check if the request was successful (status code 200)
        response.raise_for_status()
        print("Web page downloaded successfully.")

        # 2. Use pandas.read_html, specifying that the first two rows (0, 1)
        #    are the header. We pass response.text via io.StringIO.
        tables = pd.read_html(io.StringIO(response.text), header=[0, 1])

        if not tables or len(tables) < 2:
            print("Error: The requested table (index 1) was not found on the page.")
            return None

        # 3. The table of interest is the second one found (index 1).
        df = tables[1]

        # 4. The header has multiple levels (MultiIndex). Simplify it.
        new_columns = []
        for col_level1, col_level2 in df.columns:
            # If the first header level contains 'Year', the column is 'Year'.
            if 'Year' in col_level1:
                new_columns.append('Year')
            # Otherwise, join the two levels to create a unique name.
            else:
                # Replace potential newline characters for cleaner names
                col_level1 = col_level1.replace('\n', ' ').strip()
                col_level2 = col_level2.replace('\n', ' ').strip()
                new_columns.append(f"{col_level1} {col_level2}")

        df.columns = new_columns

        # Convert the 'Year' column to string for consistent cleaning
        df['Year'] = df['Year'].astype(str)

        print("Data extracted and converted to DataFrame.")
        return df

    except requests.exceptions.RequestException as e:
        print(f"Error during HTTP request: {e}")
        return None
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
        return None


# URL of the page to scrape data from
URL_GEOMAGNETIC_POLES = "https://wdc.kugi.kyoto-u.ac.jp/poles/polesexp.html"

# Execute the function and get the DataFrame
geomagnetic_data = scrape_geomagnetic_poles(URL_GEOMAGNETIC_POLES)

# If data was extracted successfully, process it
if geomagnetic_data is not None:
    print("\n--- Extracted Geomagnetic Pole Data ---")
    # print(geomagnetic_data.to_string()) # Print omitted for brevity

    # --- SECTION: Process, Interpolate, and save the data to a .dat file ---
    try:
        # 1. Select the relevant columns (ensure correct column names)
        lat_col_name = 'North geomagnetic pole Lat.'
        lon_col_name = 'North geomagnetic pole Long.'
        columns_to_process = ['Year', lat_col_name, lon_col_name]
        data_to_process = geomagnetic_data[columns_to_process].copy()

        # 2. Function to convert coordinates from string to float with the correct sign
        def convert_geo_coord(coord_str):
            """Converts a coordinate string (e.g., '78.7N') into a float number."""
            coord_str = str(coord_str).strip()
            if not coord_str or coord_str.lower() in ('nan', 'none', '-'):
                return None
            
            # Extract the numerical part and the direction (the last character)
            value_str = coord_str[:-1]
            direction = coord_str[-1].upper()

            try:
                value = float(value_str)
                # Apply a negative sign for South (S) and West (W)
                if direction in ['S', 'W']:
                    return -value
                return value
            except (ValueError, TypeError):
                # Returns None if the number conversion fails
                return None

        # Apply the conversion function to the latitude and longitude columns
        data_to_process[lat_col_name] = data_to_process[lat_col_name].apply(convert_geo_coord)
        data_to_process[lon_col_name] = data_to_process[lon_col_name].apply(convert_geo_coord)

        # Remove any rows where the conversion failed in lat or lon columns (resulting in NaN)
        data_to_process.dropna(subset=[lat_col_name, lon_col_name], inplace=True)
        
        # Convert 'Year' to integer for proper time-series indexing
        data_to_process['Year'] = data_to_process['Year'].astype(int)

        # 3. INTERPOLATION LOGIC
        # Set 'Year' as the index for time-series operations
        data_to_process.set_index('Year', inplace=True)
        
        # Create a new index with annual steps (from min year to max year of data)
        min_year = data_to_process.index.min()
        max_year = data_to_process.index.max()
        # Ensure the index covers every year in the range
        new_index = pd.Index(range(min_year, max_year + 1), name='Year')

        # Reindex the DataFrame to insert rows with NaN for missing years
        data_interpolated = data_to_process.reindex(new_index)
        
        # Perform linear interpolation (fill NaN values between known points)
        # 'linear' method is used, treating the index (Year) as the variable to interpolate over.
        data_interpolated.interpolate(method='linear', axis=0, inplace=True)
        
        # Reset the index to have 'Year' as a column again
        data_interpolated.reset_index(inplace=True)

        # Handle potential NaNs at the beginning/end if extrapolation is required (optional, but good practice)
        # If the first or last point is NaN (e.g., if the data started/ended with NaNs that were kept after dropna)
        # we might need to handle them, but for this dataset, they should be filled by reindex/interpolate.
        data_interpolated.dropna(inplace=True)


        # 4. Save the file
        output_dir = 'data'
        os.makedirs(output_dir, exist_ok=True)
        output_filename = os.path.join(output_dir, 'polos_igrf_swarm.dat')

        # Manually write the file to use a multi-character separator (', ') and no header
        with open(output_filename, 'w') as f:
            for index, row in data_interpolated.iterrows():
                # Format Year as integer and Lat/Long as float with 4 decimal places
                line = f"{int(row['Year'])}, {row[lat_col_name]:.4f}, {row[lon_col_name]:.4f}"
                f.write(line + '\n')

        print(f"\nSuccessfully interpolated data (annual step) saved to '{output_filename}'.")
        print(f"The file contains {len(data_interpolated)} records from {min_year} to {max_year}.")

    except KeyError as e:
        print(f"\nError: One of the requested columns was not found. Check the column names. {e}")
    except Exception as e:
        print(f"\nAn error occurred while saving the file: {e}")
# Out:
# Contacting URL: https://wdc.kugi.kyoto-u.ac.jp/poles/polesexp.html...
# Web page downloaded successfully.
# Data extracted and converted to DataFrame.
#
# --- Extracted Geomagnetic Pole Data ---
#
# Successfully interpolated data (annual step) saved to 'data\polos_igrf_swarm.dat'.
# The file contains 131 records from 1900 to 2030.
